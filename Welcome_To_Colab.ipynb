# %%
# Data Handling
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Warnings
import warnings
warnings.filterwarnings('ignore')

# Date & Time
from datetime import datetime

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ce941ca-de03-4fb3-9837-9ba0e1c2b320" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ce941ca-de03-4fb3-9837-9ba0e1c2b320">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_name = list(uploaded.keys())[0]

df = pd.read_csv(file_name)

print("File loaded successfully!")
print("Shape:", df.shape)
# Out:
# File loaded successfully!
# Shape: (30000, 38)

# %%
print("Dataset Shape:", df.shape)

print("\nFirst 5 Rows:")
display(df.head())

print("\nColumn Names:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)
# Out:
# Dataset Shape: (30000, 38)
#
# First 5 Rows:
#   Line_Item_ID    Order_ID           Order_Date            Ship_Date  \
# 0  ITEM-000001  ORD-100001  2025-09-02 00:00:00  2025-09-07 00:00:00
# 1  ITEM-000002  ORD-100002  2026-05-31 00:00:00  2026-06-05 00:00:00
# 2  ITEM-000003  ORD-100003  2025-08-15 00:00:00  2025-08-22 00:00:00
# 3  ITEM-000004  ORD-100004  2025-10-21 00:00:00  2025-10-28 00:00:00
# 4  ITEM-000005  ORD-100005  2025-07-05 00:00:00  2025-07-11 00:00:00
#
#   Customer_ID Customer_Type  Customer_Age Customer_Gender Customer_Segment  \
# 0  CUST-14425           New            26          Female         Consumer
# 1  CUST-02166           New            18          Female        Corporate
# 2  CUST-04225           New            51            Male         Consumer
# 3  CUST-12155           New            60          Female        Corporate
# 4  CUST-09335           New            64          Female         Consumer
#
# ...

# %%
missing_values = df.isnull().sum()

print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# Line_Item_ID              0
# Order_ID                  0
# Order_Date                0
# Ship_Date                 0
# Customer_ID               0
# Customer_Type             0
# Customer_Age              0
# Customer_Gender           0
# Customer_Segment          0
# City                      0
# State                     0
# Region                    0
# Product_ID                0
# Category                  0
# Sub_Category              0
# Product_Name              0
# Sales_Channel             0
# Device_Type               0
# Traffic_Source            0
# Payment_Method            0
# Shipping_Mode             0
# Order_Status              0
# Return_Flag               0
# Quantity                  0
# Unit_Price_INR            0
# Unit_Cost_INR             0
# Discount_Pct              0
# Shipping_Cost_INR         0
# Gross_Sales_INR           0
# Discount_Amount_INR       0
# Net_Sales_INR             0
# COGS_INR                  0
# ...

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

print("\nMissing Value Percentage:")
print(missing_percentage)
# Out:
# Missing Value Percentage:
# Line_Item_ID           0.00
# Order_ID               0.00
# Order_Date             0.00
# Ship_Date              0.00
# Customer_ID            0.00
# Customer_Type          0.00
# Customer_Age           0.00
# Customer_Gender        0.00
# Customer_Segment       0.00
# City                   0.00
# State                  0.00
# Region                 0.00
# Product_ID             0.00
# Category               0.00
# Sub_Category           0.00
# Product_Name           0.00
# Sales_Channel          0.00
# Device_Type            0.00
# Traffic_Source         0.00
# Payment_Method         0.00
# Shipping_Mode          0.00
# Order_Status           0.00
# Return_Flag            0.00
# Quantity               0.00
# Unit_Price_INR         0.00
# Unit_Cost_INR          0.00
# Discount_Pct           0.00
# Shipping_Cost_INR      0.00
# Gross_Sales_INR        0.00
# Discount_Amount_INR    0.00
# Net_Sales_INR          0.00
# COGS_INR               0.00
# ...

# %%
print("Customer Rating - Missing Values:")
print(df["Customer_Rating"].isnull().sum())

print("\nCustomer Rating - Existing Values:")
print(df["Customer_Rating"].describe())
# Out:
# Customer Rating - Missing Values:
# 2007
#
# Customer Rating - Existing Values:
# count    27993.000000
# mean         3.820098
# std          1.088602
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          5.000000
# Name: Customer_Rating, dtype: float64

# %%
print(df["Customer_Rating"].value_counts(dropna=False).sort_index())
# Out:
# Customer_Rating
# 1.0     1369
# 2.0     2129
# 3.0     4956
# 4.0    11254
# 5.0     8285
# NaN     2007
# Name: count, dtype: int64

# %%
# Check duplicate rows
duplicate_count = df.duplicated().sum()

print("Total Duplicate Rows:", duplicate_count)
# Out:
# Total Duplicate Rows: 0

# %%
print("Duplicate Order IDs:", df["Order_ID"].duplicated().sum())
# Out:
# Duplicate Order IDs: 0

# %%
print(df[["Order_Date", "Ship_Date"]].dtypes)
# Out:
# Order_Date    object
# Ship_Date     object
# dtype: object

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"], errors="coerce")
df["Ship_Date"] = pd.to_datetime(df["Ship_Date"], errors="coerce")

# %%
print(df[["Order_Date", "Ship_Date"]].dtypes)
# Out:
# Order_Date    datetime64[ns]
# Ship_Date     datetime64[ns]
# dtype: object

# %%
df.describe()
# Out:
#                        Order_Date                      Ship_Date  \
# count                       30000                          30000
# mean   2025-11-01 18:06:11.520000  2025-11-06 04:53:48.480000512
# min           2025-01-01 00:00:00            2025-01-01 00:00:00
# 25%           2025-06-22 00:00:00            2025-06-26 18:00:00
# 50%           2025-11-05 00:00:00            2025-11-10 00:00:00
# 75%           2026-03-13 00:00:00            2026-03-17 00:00:00
# max           2026-08-24 00:00:00            2026-08-24 00:00:00
# std                           NaN                            NaN
#
#        Customer_Age      Quantity  Unit_Price_INR  Unit_Cost_INR  \
# count  30000.000000  30000.000000    30000.000000   30000.000000
# mean      41.414900      1.515700     5371.252098    3635.219700
# min       18.000000      1.000000      597.180000     248.110000
# 25%       30.000000      1.000000     1298.807500     592.782500
# ...

# %%
df[[
    "Quantity",
    "Unit_Price_INR",
    "Unit_Cost_INR"
]].describe()
# Out:
#            Quantity  Unit_Price_INR  Unit_Cost_INR
# count  30000.000000    30000.000000   30000.000000
# mean       1.515700     5371.252098    3635.219700
# std        0.850555    10787.843873    8673.319268
# min        1.000000      597.180000     248.110000
# 25%        1.000000     1298.807500     592.782500
# 50%        1.000000     2083.005000    1071.545000
# 75%        2.000000     4505.090000    2706.832500
# max        5.000000    62637.610000   50110.090000

# %%
for i, col in enumerate(df.columns, 1):
    print(i, col)
# Out:
# 1 Line_Item_ID
# 2 Order_ID
# 3 Order_Date
# 4 Ship_Date
# 5 Customer_ID
# 6 Customer_Type
# 7 Customer_Age
# 8 Customer_Gender
# 9 Customer_Segment
# 10 City
# 11 State
# 12 Region
# 13 Product_ID
# 14 Category
# 15 Sub_Category
# 16 Product_Name
# 17 Sales_Channel
# 18 Device_Type
# 19 Traffic_Source
# 20 Payment_Method
# 21 Shipping_Mode
# 22 Order_Status
# 23 Return_Flag
# 24 Quantity
# 25 Unit_Price_INR
# 26 Unit_Cost_INR
# 27 Discount_Pct
# 28 Shipping_Cost_INR
# 29 Gross_Sales_INR
# 30 Discount_Amount_INR
# 31 Net_Sales_INR
# 32 COGS_INR
# 33 Refund_Amount_INR
# 34 Realized_Sales_INR
# 35 Profit_INR
# 36 Profit_Margin_Pct
# 37 Delivery_Days
# 38 Customer_Rating

# %%
df[[
    "Gross_Sales_INR",
    "Discount_Amount_INR",
    "Net_Sales_INR",
    "COGS_INR",
    "Refund_Amount_INR",
    "Realized_Sales_INR",
    "Profit_INR",
    "Profit_Margin_Pct"
]].describe()
# Out:
#        Gross_Sales_INR  Discount_Amount_INR  Net_Sales_INR       COGS_INR  \
# count     30000.000000         30000.000000   30000.000000   30000.000000
# mean       8209.241300           854.499483    7070.534001    5078.747293
# std       19617.626294          2446.934645   17340.468597   14995.131944
# min         597.440000             0.000000       0.000000       0.000000
# 25%        1543.652500           123.827250    1286.477750     596.365000
# 50%        2963.240000           279.021750    2531.737750    1307.725000
# 75%        6189.780000           639.323250    5342.785500    3200.485000
# max      309601.850000         76861.550000  283929.300000  247681.500000
#
#        Refund_Amount_INR  Realized_Sales_INR    Profit_INR  Profit_Margin_Pct
# count       30000.000000        30000.000000  30000.000000       30000.000000
# mean          356.840410         6713.693591   1603.029731           0.356344
# ...

# %%
total_gross_sales = df["Gross_Sales_INR"].sum()
total_net_sales = df["Net_Sales_INR"].sum()
total_realized_sales = df["Realized_Sales_INR"].sum()
total_profit = df["Profit_INR"].sum()
total_discount = df["Discount_Amount_INR"].sum()
total_refund = df["Refund_Amount_INR"].sum()

print("Total Gross Sales      :", round(total_gross_sales, 2))
print("Total Net Sales        :", round(total_net_sales, 2))
print("Total Realized Sales   :", round(total_realized_sales, 2))
print("Total Profit           :", round(total_profit, 2))
print("Total Discount         :", round(total_discount, 2))
print("Total Refund           :", round(total_refund, 2))
# Out:
# Total Gross Sales      : 246277239.01
# Total Net Sales        : 212116020.04
# Total Realized Sales   : 201410807.72
# Total Profit           : 48090891.94
# Total Discount         : 25634984.48
# Total Refund           : 10705212.32

# %% [markdown]
# Realized Sales ₹20.14 Cr ke against Profit ₹4.81 Cr hai, yani overall realized-sales basis par profit roughly 23.87% hai.

# %%
status_count = df["Order_Status"].value_counts()

print(status_count)
# Out:
# Order_Status
# Delivered     26566
# Returned       1427
# Cancelled      1188
# Shipped         675
# Processing       79
# Pending          65
# Name: count, dtype: int64

# %%
status_percentage = df["Order_Status"].value_counts(normalize=True) * 100

print(status_percentage.round(2))
# Out:
# Order_Status
# Delivered     88.55
# Returned       4.76
# Cancelled      3.96
# Shipped        2.25
# Processing     0.26
# Pending        0.22
# Name: proportion, dtype: float64

# %%
return_count = df["Return_Flag"].value_counts()

print(return_count)
# Out:
# Return_Flag
# No     28573
# Yes     1427
# Name: count, dtype: int64

# %%
return_percentage = df["Return_Flag"].value_counts(normalize=True) * 100

print(return_percentage.round(2))
# Out:
# Return_Flag
# No     95.24
# Yes     4.76
# Name: proportion, dtype: float64

# %%
return_analysis = df.groupby("Return_Flag").agg(
    Orders=("Order_ID", "count"),
    Realized_Sales=("Realized_Sales_INR", "sum"),
    Refund=("Refund_Amount_INR", "sum"),
    Profit=("Profit_INR", "sum")
)

print(return_analysis)
# Out:
#              Orders  Realized_Sales        Refund        Profit
# Return_Flag
# No            28573    2.014108e+08  0.000000e+00  4.813733e+07
# Yes            1427    0.000000e+00  1.070521e+07 -4.643700e+04

# %%
return_analysis["Profit_Margin_%"] = (
    return_analysis["Profit"] / return_analysis["Realized_Sales"] * 100
)

print(return_analysis.round(2))
# Out:
#              Orders  Realized_Sales       Refund       Profit  Profit_Margin_%
# Return_Flag
# No            28573    2.014108e+08         0.00  48137328.94             23.9
# Yes            1427    0.000000e+00  10705212.32    -46437.00             -inf

# %% [markdown]
# Main insight
#
# 1. Return rate = 4.76%
# 1,427 out of 30,000 records returned .
#
# 2. Returned orders Realized Sales = ₹0
# Ye logical hai, kyunki returned orders  sales ultimately realize nahi hui.
#
# 3. Returns ka direct financial impact = ₹1.07 Cr refund
#
# 4. Returned orders par overall Profit = -₹46,437
# Matlab returned transactions collectively loss-making hain.

# %%
category_returns = df.groupby("Category").agg(
    Total_Orders=("Order_ID", "count"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum()),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Total_Profit=("Profit_INR", "sum")
)

category_returns["Return_Rate_%"] = (
    category_returns["Returned_Orders"] /
    category_returns["Total_Orders"] * 100
)

category_returns = category_returns.sort_values(
    "Return_Rate_%", ascending=False
)

print(category_returns.round(2))
# Out:
#                 Total_Orders  Returned_Orders  Total_Refund  Total_Profit  \
# Category
# Books                   1932              110     181397.87    1268049.96
# Grocery                 1929               99      95803.77     450663.37
# Pet Supplies            1913               97     273524.23    1696635.62
# Fashion                 4044              200     657040.92    5233231.91
# Home & Kitchen          4072              196     976779.93    6759708.74
# Sports                  2002               96     362813.14    2943538.77
# Furniture               1968               94    1061465.35    5172984.94
# Beauty                  3068              141     189700.07    2096495.98
# Electronics             5033              228    6210478.49   16513179.67
# Automotive              2021               86     482619.80    3557936.10
# Toys                    2018               80     213588.75    2398466.88
#
#                 Return_Rate_%
# Category
# ...

# %% [markdown]
# Highest Return Rate: 📚 Books — 5.69%
#
# Lowest Return Rate: 🧸 Toys — 3.96%

# %%
category_profit = df.groupby("Category").agg(
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Orders=("Order_ID", "count")
)

category_profit["Profit_Margin_%"] = (
    category_profit["Total_Profit"] /
    category_profit["Total_Sales"] * 100
)

category_profit = category_profit.sort_values(
    "Total_Profit", ascending=False
)

print(category_profit.round(2))
# Out:
#                  Total_Sales  Total_Profit  Total_Orders  Profit_Margin_%
# Category
# Electronics     1.160483e+08   16513179.67          5033            14.23
# Home & Kitchen  1.748387e+07    6759708.74          4072            38.66
# Fashion         1.138593e+07    5233231.91          4044            45.96
# Furniture       1.981540e+07    5172984.94          1968            26.11
# Automotive      1.055978e+07    3557936.10          2021            33.69
# Sports          7.619502e+06    2943538.77          2002            38.63
# Toys            5.429559e+06    2398466.88          2018            44.17
# Beauty          3.698403e+06    2096495.98          3068            56.69
# Pet Supplies    4.948905e+06    1696635.62          1913            34.28
# Books           2.743873e+06    1268049.96          1932            46.21
# Grocery         1.677245e+06     450663.37          1929            26.87

# %% [markdown]
# Category-wise Profit Analysis
# 🏆 Highest Total Profit
#
# Electronics → ₹1.65 Crore
# Electronics Profit Margin = 14.23%
# Highest Profit Margin
# Beauty → 56.69%

# %% [markdown]
# Important business Insight
#  Highest profit ≠ highest profit margin

# %%
df["Order_Month"] = df["Order_Date"].dt.to_period("M").astype(str)

monthly_sales = df.groupby("Order_Month").agg(
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Orders=("Order_ID", "count")
)

print(monthly_sales)
# Out:
#               Total_Sales  Total_Profit  Total_Orders
# Order_Month
# 2025-01      9.074821e+06  2.381829e+06          1352
# 2025-02      8.175492e+06  2.045807e+06          1178
# 2025-03      8.205397e+06  2.147802e+06          1309
# 2025-04      8.442370e+06  2.267252e+06          1309
# 2025-05      9.843531e+06  2.409006e+06          1332
# 2025-06      1.053447e+07  2.575353e+06          1371
# 2025-07      9.001234e+06  2.146019e+06          1256
# 2025-08      1.093992e+07  2.811450e+06          1687
# 2025-09      8.294658e+06  2.204639e+06          1287
# 2025-10      1.628677e+07  3.099574e+06          2526
# 2025-11      1.500919e+07  2.932970e+06          2473
# 2025-12      1.384800e+07  2.790193e+06          2280
# 2026-01      8.527167e+06  2.287596e+06          1373
# 2026-02      9.094140e+06  2.151898e+06          1197
# 2026-03      9.278400e+06  2.312662e+06          1379
# 2026-04      8.342660e+06  2.145580e+06          1342
# ...

# %%
monthly_profit = df.groupby("Order_Month").agg(
    Total_Profit=("Profit_INR", "sum"),
    Total_Sales=("Realized_Sales_INR", "sum")
)

monthly_profit["Profit_Margin_%"] = (
    monthly_profit["Total_Profit"] /
    monthly_profit["Total_Sales"] * 100
)

print(monthly_profit.round(2))
# Out:
#              Total_Profit  Total_Sales  Profit_Margin_%
# Order_Month
# 2025-01        2381828.79   9074821.24            26.25
# 2025-02        2045807.03   8175492.16            25.02
# 2025-03        2147801.64   8205396.66            26.18
# 2025-04        2267252.15   8442370.39            26.86
# 2025-05        2409006.06   9843531.12            24.47
# 2025-06        2575353.00  10534469.57            24.45
# 2025-07        2146019.44   9001233.86            23.84
# 2025-08        2811450.04  10939919.32            25.70
# 2025-09        2204638.80   8294658.22            26.58
# 2025-10        3099574.26  16286770.38            19.03
# 2025-11        2932969.55  15009193.64            19.54
# 2025-12        2790192.54  13847996.08            20.15
# 2026-01        2287596.15   8527167.04            26.83
# 2026-02        2151897.96   9094140.36            23.66
# 2026-03        2312662.27   9278399.84            24.93
# 2026-04        2145580.29   8342660.49            25.72
# ...

# %% [markdown]
# Step 19 — Monthly Profit Analysis
# 🏆 Highest total profit: October 2025 → ₹30.996 lakh
# 🥈 November 2025 → ₹29.33 lakh
# 🥉 December 2025 → ₹27.90 lakh
# Highest profit margin: January 2026 → 26.83%
# Lowest profit margin: October 2025 → 19.03%

# %%
customer_segment = df["Customer_Segment"].value_counts()

print(customer_segment)
# Out:
# Customer_Segment
# Consumer       21553
# Corporate       5450
# Home Office     2997
# Name: count, dtype: int64

# %%
customer_segment_pct = (
    df["Customer_Segment"].value_counts(normalize=True) * 100
)

print(customer_segment_pct.round(2))
# Out:
# Customer_Segment
# Consumer       71.84
# Corporate      18.17
# Home Office     9.99
# Name: proportion, dtype: float64

# %%
segment_analysis = df.groupby("Customer_Segment").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum")
)

segment_analysis["Profit_Margin_%"] = (
    segment_analysis["Total_Profit"] /
    segment_analysis["Total_Sales"] * 100
)

print(segment_analysis.round(2))
# Out:
#                   Total_Orders   Total_Sales  Total_Profit  Total_Refund  \
# Customer_Segment
# Consumer                 21553  1.450620e+08   34654587.49    7833620.58
# Corporate                 5450  3.695625e+07    8735856.05    1899838.86
# Home Office               2997  1.939254e+07    4700448.39     971752.87
#
#                   Profit_Margin_%
# Customer_Segment
# Consumer                    23.89
# Corporate                   23.64
# Home Office                 24.24

# %%
print(df["Customer_Type"].value_counts())
# Out:
# Customer_Type
# Returning    15198
# New          14802
# Name: count, dtype: int64

# %%
print(
    (df["Customer_Type"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Customer_Type
# Returning    50.66
# New          49.34
# Name: proportion, dtype: float64

# %%
customer_type_analysis = df.groupby("Customer_Type").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum")
)

customer_type_analysis["Profit_Margin_%"] = (
    customer_type_analysis["Total_Profit"] /
    customer_type_analysis["Total_Sales"] * 100
)

print(customer_type_analysis.round(2))
# Out:
#                Total_Orders   Total_Sales  Total_Profit  Total_Refund  \
# Customer_Type
# New                   14802  9.772649e+07   23509747.16    5590156.86
# Returning             15198  1.036843e+08   24581144.77    5115055.46
#
#                Profit_Margin_%
# Customer_Type
# New                      24.06
# Returning                23.71

# %% [markdown]
# 🔎 Business findings
#  1. Returning customers zyada orders, sales aur total profit generate kar rahe hain.
# 2. Returning customers ki sales ≈ ₹10.37 Cr hai.
# New customers ki sales ≈ ₹9.77 Cr hai.
#  3. Lekin New customers ka profit margin 24.06% hai, jo Returning customers ke 23.71% se slightly higher hai.
# 4. Returning customers ka refund bhi ₹51.15 lakh hai, jo New customers ke ₹55.90 lakh se lower hai.

# %%
print(df["Customer_Age"].describe())
# Out:
# count    30000.000000
# mean        41.414900
# std         13.810505
# min         18.000000
# 25%         30.000000
# 50%         41.000000
# 75%         53.000000
# max         65.000000
# Name: Customer_Age, dtype: float64

# %%
bins = [18, 25, 35, 45, 55, 65, 100]
labels = [
    "18-24",
    "25-34",
    "35-44",
    "45-54",
    "55-64",
    "65+"
]

df["Age_Group"] = pd.cut(
    df["Customer_Age"],
    bins=bins,
    labels=labels,
    right=False
)

print(df["Age_Group"].value_counts().sort_index())
# Out:
# Age_Group
# 18-24    4380
# 25-34    6286
# 35-44    6357
# 45-54    6194
# 55-64    6177
# 65+       606
# Name: count, dtype: int64

# %%
age_analysis = df.groupby("Age_Group", observed=True).agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum")
)

age_analysis["Profit_Margin_%"] = (
    age_analysis["Total_Profit"] /
    age_analysis["Total_Sales"] * 100
)

print(age_analysis.round(2))
# Out:
#            Total_Orders  Total_Sales  Total_Profit  Total_Refund  \
# Age_Group
# 18-24              4380  29529695.94    7131629.50    1960061.01
# 25-34              6286  39810782.50    9737143.10    2303989.37
# 35-44              6357  43162082.49   10211056.24    2157836.57
# 45-54              6194  42458353.93   10112018.62    2196953.25
# 55-64              6177  41666252.62    9853866.84    1912132.21
# 65+                 606   4783640.25    1045177.64     174239.90
#
#            Profit_Margin_%
# Age_Group
# 18-24                24.15
# 25-34                24.46
# 35-44                23.66
# 45-54                23.82
# 55-64                23.65
# 65+                  21.85

# %% [markdown]
# Important findings
#
# 🏆 Highest Sales: 35–44 → ₹4.32 Cr
#
# 🏆 Highest Profit: 35–44 → ₹1.02 Cr
#
# 📈 Highest Margin: 25–34 → 24.46%
#
# 📉 Lowest Margin: 65+ → 21.85%
#
# 35–44 age group generates the highest sales and profit, while 25–34 has the highest profit margin.

# %%
print(df["Customer_Gender"].value_counts())

print(
    (df["Customer_Gender"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Customer_Gender
# Female               14552
# Male                 14312
# Prefer not to say      578
# Non-binary             558
# Name: count, dtype: int64
# Customer_Gender
# Female               48.51
# Male                 47.71
# Prefer not to say     1.93
# Non-binary            1.86
# Name: proportion, dtype: float64

# %%
gender_analysis = df.groupby("Customer_Gender").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

gender_analysis["Profit_Margin_%"] = (
    gender_analysis["Total_Profit"] /
    gender_analysis["Total_Sales"] * 100
)

gender_analysis["Return_Rate_%"] = (
    gender_analysis["Returned_Orders"] /
    gender_analysis["Total_Orders"] * 100
)

print(gender_analysis.round(2))
# Out:
#                    Total_Orders  Total_Sales  Total_Profit  Total_Refund  \
# Customer_Gender
# Female                    14552  96194403.93   23391079.85    6027234.36
# Male                      14312  98009978.41   22967503.96    4184081.99
# Non-binary                  558   3511032.16     862871.56     220402.55
# Prefer not to say           578   3695393.23     869436.57     273493.42
#
#                    Returned_Orders  Profit_Margin_%  Return_Rate_%
# Customer_Gender
# Female                         702            24.32           4.82
# Male                           671            23.43           4.69
# Non-binary                      31            24.58           5.56
# Prefer not to say               23            23.53           3.98

# %% [markdown]
# Male customers generate the highest sales, while Female customers generate the highest total profit, suggesting that sales volume and profitability differ across customer groups

# %%
print(df["Region"].value_counts())

print(
    (df["Region"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Region
# South        7578
# North        7433
# West         6017
# East         4373
# Central      3051
# Northeast    1548
# Name: count, dtype: int64
# Region
# South        25.26
# North        24.78
# West         20.06
# East         14.58
# Central      10.17
# Northeast     5.16
# Name: proportion, dtype: float64

# %% [markdown]
# Returning customers contribute higher sales and total profit, while new customers have a slightly higher profit margin. This indicates that customer retention drives revenue scale, whereas new-customer transactions are marginally more profitable."

# %%
region_analysis = df.groupby("Region").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

region_analysis["Profit_Margin_%"] = (
    region_analysis["Total_Profit"] /
    region_analysis["Total_Sales"] * 100
)

region_analysis["Return_Rate_%"] = (
    region_analysis["Returned_Orders"] /
    region_analysis["Total_Orders"] * 100
)

region_analysis = region_analysis.sort_values(
    "Total_Sales", ascending=False
)

print(region_analysis.round(2))
# Out:
#            Total_Orders  Total_Sales  Total_Profit  Total_Refund  \
# Region
# North              7433  52715450.09   12296028.73    2925552.13
# South              7578  48842266.74   11942998.26    2977732.37
# West               6017  40262907.10    9443839.99    1612746.60
# East               4373  28871940.29    7022081.60    1415064.43
# Central            3051  20309812.29    4908999.07    1218463.42
# Northeast          1548  10408431.21    2476944.28     555653.37
#
#            Returned_Orders  Profit_Margin_%  Return_Rate_%
# Region
# North                  352            23.33           4.74
# South                  376            24.45           4.96
# West                   282            23.46           4.69
# East                   203            24.32           4.64
# Central                147            24.17           4.82
# Northeast               67            23.80           4.33

# %% [markdown]
# North generates the highest sales and profit, while South has the highest profit margin.

# %%
state_analysis = df.groupby("State").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

state_analysis["Profit_Margin_%"] = (
    state_analysis["Total_Profit"] /
    state_analysis["Total_Sales"] * 100
)

state_analysis["Return_Rate_%"] = (
    state_analysis["Returned_Orders"] /
    state_analysis["Total_Orders"] * 100
)

state_analysis = state_analysis.sort_values(
    "Total_Sales", ascending=False
)

print(state_analysis.round(2))
# Out:
#                 Total_Orders  Total_Sales  Total_Profit  Total_Refund  \
# State
# Maharashtra             2975  20313038.97    4746983.75     776478.26
# Madhya Pradesh          3051  20309812.29    4908999.07    1218463.42
# Gujarat                 3042  19949868.12    4696856.23     836268.34
# Tamil Nadu              2991  19485826.98    4618688.80     904300.54
# Rajasthan               1480  11437114.42    2523041.52     462921.29
# Chandigarh              1474  11330997.96    2680127.90     753615.04
# Assam                   1548  10408431.21    2476944.28     555653.37
# Haryana                 1489  10365834.96    2415249.50     624159.26
# Delhi                   1476  10148628.99    2324566.44     615725.24
# Telangana               1537   9844853.99    2452933.69     549812.25
# Kerala                  1577   9830788.57    2475669.99    1064977.10
# West Bengal             1435   9693696.74    2361650.93     597613.98
# ...

# %% [markdown]
# Maharashtra has the highest sales, but Madhya Pradesh has the highest profit. Kerala has the highest profit margi
#
# sales ≠ profit ≠ margin

# %%
top5_states_sales = (
    state_analysis
    .sort_values("Total_Sales", ascending=False)
    .head(5)
)

print(top5_states_sales[[
    "Total_Orders",
    "Total_Sales",
    "Total_Profit",
    "Profit_Margin_%"
]].round(2))
# Out:
#                 Total_Orders  Total_Sales  Total_Profit  Profit_Margin_%
# State
# Maharashtra             2975  20313038.97    4746983.75            23.37
# Madhya Pradesh          3051  20309812.29    4908999.07            24.17
# Gujarat                 3042  19949868.12    4696856.23            23.54
# Tamil Nadu              2991  19485826.98    4618688.80            23.70
# Rajasthan               1480  11437114.42    2523041.52            22.06

# %%
import matplotlib.pyplot as plt

top5 = state_analysis.sort_values(
    "Total_Sales", ascending=False
).head(5)

plt.figure(figsize=(10, 6))

plt.bar(
    top5.index,
    top5["Total_Sales"]
)

plt.title("Top 5 States by Realized Sales")
plt.xlabel("State")
plt.ylabel("Realized Sales (₹)")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top5_products = (
    df.groupby("Product_Name")
      .agg(
          Total_Sales=("Realized_Sales_INR", "sum"),
          Total_Profit=("Profit_INR", "sum"),
          Total_Orders=("Order_ID", "count")
      )
      .sort_values("Total_Sales", ascending=False)
      .head(5)
)

print(top5_products.round(2))
# Out:
#                         Total_Sales  Total_Profit  Total_Orders
# Product_Name
# ApexBook 14 Laptop      73847062.45    7967405.15          1002
# Nova X5 Smartphone      31313275.14    4777661.45          1004
# Ergonomic Office Chair  12080419.06    3029494.81           962
# Digital Air Fryer        8758901.60    2648412.42          1039
# Modular Bookshelf        7734985.83    2143490.13          1006

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    top5_products.index,
    top5_products["Total_Sales"]
)

plt.title("Top 5 Products by Realized Sales")
plt.xlabel("Product")
plt.ylabel("Realized Sales (₹)")

plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
top5_profit_products = (
    df.groupby("Product_Name")
      .agg(
          Total_Profit=("Profit_INR", "sum"),
          Total_Sales=("Realized_Sales_INR", "sum"),
          Total_Orders=("Order_ID", "count")
      )
      .sort_values("Total_Profit", ascending=False)
      .head(5)
)

print(top5_profit_products.round(2))
# Out:
#                         Total_Profit  Total_Sales  Total_Orders
# Product_Name
# ApexBook 14 Laptop        7967405.15  73847062.45          1002
# Nova X5 Smartphone        4777661.45  31313275.14          1004
# Ergonomic Office Chair    3029494.81  12080419.06           962
# Digital Air Fryer         2648412.42   8758901.60          1039
# Smart Dash Camera         2169040.50   6975047.06          1008

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    top5_profit_products.index,
    top5_profit_products["Total_Profit"]
)

plt.title("Top 5 Products by Profit")
plt.xlabel("Product")
plt.ylabel("Total Profit (₹)")

plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
print(df["Sales_Channel"].value_counts())

print(
    (df["Sales_Channel"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Sales_Channel
# Mobile App     15394
# Website        10037
# Marketplace     4569
# Name: count, dtype: int64
# Sales_Channel
# Mobile App     51.31
# Website        33.46
# Marketplace    15.23
# Name: proportion, dtype: float64

# %%
channel_analysis = df.groupby("Sales_Channel").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

channel_analysis["Profit_Margin_%"] = (
    channel_analysis["Total_Profit"] /
    channel_analysis["Total_Sales"] * 100
)

channel_analysis["Return_Rate_%"] = (
    channel_analysis["Returned_Orders"] /
    channel_analysis["Total_Orders"] * 100
)

print(channel_analysis.round(2))
# Out:
#                Total_Orders   Total_Sales  Total_Profit  Total_Refund  \
# Sales_Channel
# Marketplace            4569  3.093440e+07    7345316.70    1740486.22
# Mobile App            15394  1.051310e+08   24879299.73    5504315.04
# Website               10037  6.534540e+07   15866275.50    3460411.06
#
#                Returned_Orders  Profit_Margin_%  Return_Rate_%
# Sales_Channel
# Marketplace                192            23.74           4.20
# Mobile App                 738            23.67           4.79
# Website                    497            24.28           4.95

# %%
print(df["Device_Type"].value_counts())

print(
    (df["Device_Type"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Device_Type
# Mobile     23335
# Desktop     5632
# Tablet      1033
# Name: count, dtype: int64
# Device_Type
# Mobile     77.78
# Desktop    18.77
# Tablet      3.44
# Name: proportion, dtype: float64

# %%
device_analysis = df.groupby("Device_Type").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

device_analysis["Profit_Margin_%"] = (
    device_analysis["Total_Profit"] /
    device_analysis["Total_Sales"] * 100
)

device_analysis["Return_Rate_%"] = (
    device_analysis["Returned_Orders"] /
    device_analysis["Total_Orders"] * 100
)

print(device_analysis.round(2))
# Out:
#              Total_Orders   Total_Sales  Total_Profit  Total_Refund  \
# Device_Type
# Desktop              5632  3.842271e+07    9052631.45    2015122.90
# Mobile              23335  1.568066e+08   37497758.69    8126979.70
# Tablet               1033  6.181461e+06    1540501.80     563109.72
#
#              Returned_Orders  Profit_Margin_%  Return_Rate_%
# Device_Type
# Desktop                  263            23.56           4.67
# Mobile                  1114            23.91           4.77
# Tablet                    50            24.92           4.84

# %% [markdown]
# 🔎 Important findings
#  📱 Mobile → highest orders, sales and total profit.
#
#
# 📊 Tablet → highest profit margin (24.92%), but orders are very low.
#
#
# 💻 Desktop → lowest return rate among the three (4.67%).
# Mobile generates around ₹15.68 Cr realized sales, making it the most important device channel.

# %%
print(df["Traffic_Source"].value_counts())

print(
    (df["Traffic_Source"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Traffic_Source
# Organic Search    7985
# Social Media      6343
# Paid Search       5768
# Direct            5458
# Email             2658
# Affiliate         1788
# Name: count, dtype: int64
# Traffic_Source
# Organic Search    26.62
# Social Media      21.14
# Paid Search       19.23
# Direct            18.19
# Email              8.86
# Affiliate          5.96
# Name: proportion, dtype: float64

# %%
traffic_analysis = df.groupby("Traffic_Source").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

traffic_analysis["Profit_Margin_%"] = (
    traffic_analysis["Total_Profit"] /
    traffic_analysis["Total_Sales"] * 100
)

traffic_analysis["Return_Rate_%"] = (
    traffic_analysis["Returned_Orders"] /
    traffic_analysis["Total_Orders"] * 100
)

traffic_analysis = traffic_analysis.sort_values(
    "Total_Sales", ascending=False
)

print(traffic_analysis.round(2))
# Out:
#                 Total_Orders  Total_Sales  Total_Profit  Total_Refund  \
# Traffic_Source
# Organic Search          7985  53571427.09   12634938.23    1955136.56
# Social Media            6343  43864803.74   10234862.11    2562699.55
# Direct                  5458  38410187.66    9063514.53    1720645.28
# Paid Search             5768  38048681.03    9174020.99    2136231.27
# Email                   2658  16056075.11    4144488.39     804820.90
# Affiliate               1788  11459633.10    2839067.69    1525678.75
#
#                 Returned_Orders  Profit_Margin_%  Return_Rate_%
# Traffic_Source
# Organic Search              335            23.59           4.20
# Social Media                337            23.33           5.31
# Direct                      254            23.60           4.65
# Paid Search                 302            24.11           5.24
# Email                       122            25.81           4.59
# ...

# %% [markdown]
# 💼 Business Insight
#
# Organic Search is the strongest source by sales volume, while Email generates the highest profit margin. Social Media drives significant sales but has the highest return rate, indicating a potential need to improve customer targeting or product expectations

# %%
print(df["Payment_Method"].value_counts())

print(
    (df["Payment_Method"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Payment_Method
# UPI                 12674
# Credit Card          6565
# Debit Card           4189
# Cash on Delivery     2949
# Wallet               2108
# Net Banking          1515
# Name: count, dtype: int64
# Payment_Method
# UPI                 42.25
# Credit Card         21.88
# Debit Card          13.96
# Cash on Delivery     9.83
# Wallet               7.03
# Net Banking          5.05
# Name: proportion, dtype: float64

# %%
payment_analysis = df.groupby("Payment_Method").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

payment_analysis["Profit_Margin_%"] = (
    payment_analysis["Total_Profit"] /
    payment_analysis["Total_Sales"] * 100
)

payment_analysis["Return_Rate_%"] = (
    payment_analysis["Returned_Orders"] /
    payment_analysis["Total_Orders"] * 100
)

payment_analysis = payment_analysis.sort_values(
    "Total_Sales", ascending=False
)

print(payment_analysis.round(2))
# Out:
#                   Total_Orders  Total_Sales  Total_Profit  Total_Refund  \
# Payment_Method
# UPI                      12674  86648843.13   20536381.34    4802354.73
# Credit Card               6565  44208256.58   10419216.95    2277277.63
# Debit Card                4189  26988360.59    6527303.22    1297252.57
# Cash on Delivery          2949  19594938.97    4687735.54     769037.45
# Wallet                    2108  14164441.07    3406020.47     800628.46
# Net Banking               1515   9805967.37    2514234.40     758661.47
#
#                   Returned_Orders  Profit_Margin_%  Return_Rate_%
# Payment_Method
# UPI                           614            23.70           4.84
# Credit Card                   309            23.57           4.71
# Debit Card                    195            24.19           4.66
# Cash on Delivery              129            23.92           4.37
# Wallet                         93            24.05           4.41
# ...

# %% [markdown]
# 💡 Project Insight
#
# UPI is the dominant payment method by transaction volume and revenue, while Net Banking delivers the highest profit margin but also has the highest return rate.

# %%
print(df["Shipping_Mode"].value_counts())

print(
    (df["Shipping_Mode"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Shipping_Mode
# Standard    20990
# Express      6913
# Same Day     2097
# Name: count, dtype: int64
# Shipping_Mode
# Standard    69.97
# Express     23.04
# Same Day     6.99
# Name: proportion, dtype: float64

# %%
shipping_analysis = df.groupby("Shipping_Mode").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum()),
    Avg_Delivery_Days=("Delivery_Days", "mean")
)

shipping_analysis["Profit_Margin_%"] = (
    shipping_analysis["Total_Profit"] /
    shipping_analysis["Total_Sales"] * 100
)

shipping_analysis["Return_Rate_%"] = (
    shipping_analysis["Returned_Orders"] /
    shipping_analysis["Total_Orders"] * 100
)

print(shipping_analysis.round(2))
# Out:
#                Total_Orders   Total_Sales  Total_Profit  Total_Refund  \
# Shipping_Mode
# Express                6913  4.714210e+07   10826480.67    2287792.84
# Same Day               2097  1.308054e+07    2942719.60     747943.01
# Standard              20990  1.411882e+08   34321691.66    7669476.46
#
#                Returned_Orders  Avg_Delivery_Days  Profit_Margin_%  \
# Shipping_Mode
# Express                    302               2.50            22.97
# Same Day                   111               0.75            22.50
# Standard                  1014               5.50            24.31
#
#                Return_Rate_%
# Shipping_Mode
# Express                 4.37
# Same Day                5.29
# Standard                4.83

# %% [markdown]
# 💡 Strong project insight
#
# Standard shipping generates the highest revenue and profit, while Same Day shipping provides the fastest delivery but has lower profitability and the highest return rate.

# %%
bins = [0, 1, 3, 5, 7, 10, 100]

labels = [
    "0-1 Days",
    "2-3 Days",
    "4-5 Days",
    "6-7 Days",
    "8-10 Days",
    "10+ Days"
]

df["Delivery_Group"] = pd.cut(
    df["Delivery_Days"],
    bins=bins,
    labels=labels,
    right=True,
    include_lowest=True
)

print(df["Delivery_Group"].value_counts().sort_index())
# Out:
# Delivery_Group
# 0-1 Days      3314
# 2-3 Days      3950
# 4-5 Days     12352
# 6-7 Days     10384
# 8-10 Days        0
# 10+ Days         0
# Name: count, dtype: int64

# %%
delivery_analysis = df.groupby("Delivery_Group", observed=True).agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Refund=("Refund_Amount_INR", "sum"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

delivery_analysis["Profit_Margin_%"] = (
    delivery_analysis["Total_Profit"] /
    delivery_analysis["Total_Sales"] * 100
)

delivery_analysis["Return_Rate_%"] = (
    delivery_analysis["Returned_Orders"] /
    delivery_analysis["Total_Orders"] * 100
)

print(delivery_analysis.round(2))
# Out:
#                 Total_Orders  Total_Sales  Total_Profit  Total_Refund  \
# Delivery_Group
# 0-1 Days                3314  22511091.74    4978966.51    1076964.35
# 2-3 Days                3950  26437719.47    6198910.94    1568257.24
# 4-5 Days               12352  85053494.47   20095897.23    4199282.21
# 6-7 Days               10384  67408502.05   16817117.26    3860708.51
#
#                 Returned_Orders  Profit_Margin_%  Return_Rate_%
# Delivery_Group
# 0-1 Days                    149            22.12           4.50
# 2-3 Days                    185            23.45           4.68
# 4-5 Days                    610            23.63           4.94
# 6-7 Days                    483            24.95           4.65

# %% [markdown]
# "The analysis does not show a simple relationship between faster delivery and higher profitability. Longer delivery groups show higher margins, while the 4–5 day group has the highest return rate."

# %%
category_channel = pd.pivot_table(
    df,
    values="Realized_Sales_INR",
    index="Category",
    columns="Sales_Channel",
    aggfunc="sum"
)

print(category_channel.round(2))
# Out:
# Sales_Channel   Marketplace   Mobile App      Website
# Category
# Automotive       1419617.35   5496117.52   3644046.51
# Beauty            621731.36   1816367.58   1260304.15
# Books             452039.52   1414722.72    877111.00
# Electronics     17802602.13  61450603.36  36795131.98
# Fashion          1827830.07   5766427.11   3791668.94
# Furniture        2942092.12  10171137.26   6702175.51
# Grocery           234001.18    864919.85    578324.06
# Home & Kitchen   3003905.81   8784270.31   5695694.33
# Pet Supplies      705734.69   2457505.24   1785664.63
# Sports           1104542.34   4135599.31   2379360.49
# Toys              820307.11   2773332.42   1835919.78

# %% [markdown]
# Key Insights
#
# The Mobile App is the leading sales channel across every product category, with Electronics contributing the largest channel-category revenue

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

sns.heatmap(
    category_channel,
    annot=True,
    fmt=".0f",
    cmap="YlGnBu"
)

plt.title("Category-wise Sales by Sales Channel")
plt.xlabel("Sales Channel")
plt.ylabel("Category")

plt.tight_layout()
plt.show()

# %%
category_segment = pd.pivot_table(
    df,
    values="Realized_Sales_INR",
    index="Category",
    columns="Customer_Segment",
    aggfunc="sum"
)

print(category_segment.round(2))
# Out:
# Customer_Segment     Consumer    Corporate  Home Office
# Category
# Automotive         7605629.18   1910258.49   1043893.70
# Beauty             2642878.51    687277.02    368247.56
# Books              1991384.45    480007.33    272481.45
# Electronics       83512310.24  21168437.10  11367590.12
# Fashion            8053083.77   2151422.76   1181419.59
# Furniture         14479252.75   3670506.72   1665645.42
# Grocery            1228293.70    297647.46    151303.93
# Home & Kitchen    12744623.75   3223981.35   1515265.35
# Pet Supplies       3523953.36    935027.73    489923.48
# Sports             5443883.96   1411115.18    764503.00
# Toys               3836729.42   1020564.15    572265.75

# %% [markdown]
# Business Insight
#
# "Electronics is the strongest category across all customer segments, while Consumer customers contribute the majority of category sales. This indicates a strong opportunity to prioritize Electronics for both consumer and business-oriented segments."

# %%
plt.figure(figsize=(10, 7))

sns.heatmap(
    category_segment,
    annot=True,
    fmt=".0f",
    cmap="YlGnBu"
)

plt.title("Category Sales by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Category")

plt.tight_layout()
plt.show()

# %%
age_category = pd.pivot_table(
    df,
    values="Realized_Sales_INR",
    index="Age_Group",
    columns="Category",
    aggfunc="sum"
)

print(age_category.round(2))
# Out:
# Category   Automotive     Beauty      Books  Electronics     Fashion  \
# Age_Group
# 18-24      1569957.55  547484.34  391186.88  17027369.07  1827617.94
# 25-34      2132595.82  813537.59  562547.78  22233730.74  2364134.44
# 35-44      2206586.62  741206.64  573723.06  24521367.48  2406278.47
# 45-54      2115605.02  767632.69  573516.46  25007923.82  2231324.11
# 55-64      2299017.85  765608.61  574749.75  24226934.16  2324075.33
# 65+         236018.51   62933.22   68149.31   3031012.19   232495.83
#
# Category    Furniture    Grocery  Home & Kitchen  Pet Supplies      Sports  \
# Age_Group
# 18-24      2761178.53  250203.85      2534709.02     692061.13  1100466.99
# 25-34      3892726.83  381664.63      3729056.60     957901.79  1593399.32
# 35-44      4867383.68  344775.24      3869773.49    1039732.18  1479811.51
# 45-54      3874377.00  347976.64      3609150.69    1070640.68  1711703.08
# 55-64      4086235.67  332519.41      3305510.96    1068243.36  1590620.84
# ...

# %% [markdown]
# 💡 Business Insight
#
# Electronics is the dominant category across every age group, with customers aged 45–54 generating the highest Electronics sales.

# %%
plt.figure(figsize=(14, 7))

sns.heatmap(
    age_category,
    annot=True,
    fmt=".0f",
    cmap="YlGnBu"
)

plt.title("Category Sales by Age Group")
plt.xlabel("Category")
plt.ylabel("Age Group")

plt.tight_layout()
plt.show()

# %%
gender_category = pd.pivot_table(
    df,
    values="Realized_Sales_INR",
    index="Customer_Gender",
    columns="Category",
    aggfunc="sum"
)

print(gender_category.round(2))
# Out:
# Category           Automotive      Beauty       Books  Electronics  \
# Customer_Gender
# Female             5158533.84  1809368.83  1329687.70  54734297.28
# Male               5013486.84  1747556.44  1323428.33  57431399.75
# Non-binary          199702.68    75754.52    34983.02   1823538.48
# Prefer not to say   188058.01    65723.30    55774.19   2059101.95
#
# Category              Fashion   Furniture    Grocery  Home & Kitchen  \
# Customer_Gender
# Female             5515942.65  9669716.30  823014.46      8571211.24
# Male               5489813.04  9354282.18  779768.18      8201712.80
# Non-binary          173587.45   494477.99   33361.17       322605.12
# Prefer not to say   206582.97   296928.42   41101.27       388341.30
#
# Category           Pet Supplies      Sports        Toys
# Customer_Gender
# Female               2360458.37  3547423.49  2674749.76
# Male                 2417239.78  3707039.91  2544251.15
# Non-binary             78751.30   179937.44    94333.00
# ...

# %% [markdown]
# Business Insight
#
# "Electronics is the leading category across all gender groups, while male and female customers show broadly similar category preferences."

# %%
plt.figure(figsize=(14, 5))

sns.heatmap(
    gender_category,
    annot=True,
    fmt=".0f",
    cmap="YlGnBu"
)

plt.title("Category Sales by Customer Gender")
plt.xlabel("Category")
plt.ylabel("Customer Gender")

plt.tight_layout()
plt.show()

# %%
status_category = pd.crosstab(
    df["Category"],
    df["Order_Status"]
)

print(status_category)
# Out:
# Order_Status    Cancelled  Delivered  Pending  Processing  Returned  Shipped
# Category
# Automotive             72       1811        3           7        86       42
# Beauty                102       2734       10          11       141       70
# Books                  76       1689        6           8       110       43
# Electronics           185       4496       15          13       228       96
# Fashion               157       3567        4          12       200      104
# Furniture              86       1738        1           5        94       44
# Grocery                72       1708        5           2        99       43
# Home & Kitchen        168       3592        8           8       196      100
# Pet Supplies           90       1670        3           6        97       47
# Sports                 84       1774        4           3        96       41
# Toys                   96       1787        6           4        80       45

# %%
plt.figure(figsize=(12, 7))

sns.heatmap(
    status_category,
    annot=True,
    fmt="d",
    cmap="YlGnBu"
)

plt.title("Order Status by Category")
plt.xlabel("Order Status")
plt.ylabel("Category")

plt.tight_layout()
plt.show()

# %%
status_category_pct = pd.crosstab(
    df["Category"],
    df["Order_Status"],
    normalize="index"
) * 100

print(status_category_pct.round(2))
# Out:
# Order_Status    Cancelled  Delivered  Pending  Processing  Returned  Shipped
# Category
# Automotive           3.56      89.61     0.15        0.35      4.26     2.08
# Beauty               3.32      89.11     0.33        0.36      4.60     2.28
# Books                3.93      87.42     0.31        0.41      5.69     2.23
# Electronics          3.68      89.33     0.30        0.26      4.53     1.91
# Fashion              3.88      88.20     0.10        0.30      4.95     2.57
# Furniture            4.37      88.31     0.05        0.25      4.78     2.24
# Grocery              3.73      88.54     0.26        0.10      5.13     2.23
# Home & Kitchen       4.13      88.21     0.20        0.20      4.81     2.46
# Pet Supplies         4.70      87.30     0.16        0.31      5.07     2.46
# Sports               4.20      88.61     0.20        0.15      4.80     2.05
# Toys                 4.76      88.55     0.30        0.20      3.96     2.23

# %% [markdown]
# 💼 Project Insight
#
# Books have the highest proportional return rate (5.69%), while Toys have the lowest return rate (3.96%) but the highest cancellation rate (4.76%). This suggests different categories may require different strategies for reducing order losses.

# %%
plt.figure(figsize=(12, 7))

sns.heatmap(
    status_category_pct,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu"
)

plt.title("Order Status Percentage by Category")
plt.xlabel("Order Status")
plt.ylabel("Category")

plt.tight_layout()
plt.show()

# %%
traffic_channel = pd.crosstab(
    df["Traffic_Source"],
    df["Sales_Channel"]
)

print(traffic_channel)
# Out:
# Sales_Channel   Marketplace  Mobile App  Website
# Traffic_Source
# Affiliate               301         891      596
# Direct                  809        2848     1801
# Email                   427        1346      885
# Organic Search         1198        4054     2733
# Paid Search             898        2990     1880
# Social Media            936        3265     2142

# %% [markdown]
# 💼 Project Insight
#
# Mobile App is the dominant purchase channel across every traffic source, with Organic Search generating the highest number of app orders. This suggests that improving the mobile shopping experience could help maximize the value of existing traffic.

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(
    traffic_channel,
    annot=True,
    fmt="d",
    cmap="YlGnBu"
)

plt.title("Traffic Source vs Sales Channel")
plt.xlabel("Sales Channel")
plt.ylabel("Traffic Source")

plt.tight_layout()
plt.show()

# %%
payment_channel = pd.crosstab(
    df["Payment_Method"],
    df["Sales_Channel"]
)

print(payment_channel)
# Out:
# Sales_Channel     Marketplace  Mobile App  Website
# Payment_Method
# Cash on Delivery          459        1477     1013
# Credit Card               948        3373     2244
# Debit Card                614        2214     1361
# Net Banking               246         763      506
# UPI                      1988        6457     4229
# Wallet                    314        1110      684

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(
    payment_channel,
    annot=True,
    fmt="d",
    cmap="YlGnBu"
)

plt.title("Payment Method vs Sales Channel")
plt.xlabel("Sales Channel")
plt.ylabel("Payment Method")

plt.tight_layout()
plt.show()

# %%
shipping_region = pd.crosstab(
    df["Region"],
    df["Shipping_Mode"]
)

print(shipping_region)
# Out:
# Shipping_Mode  Express  Same Day  Standard
# Region
# Central            705       224      2122
# East              1021       306      3046
# North             1759       532      5142
# Northeast          349       104      1095
# South             1728       525      5325
# West              1351       406      4260

# %% [markdown]
# Project Insight
#
# Standard shipping is the dominant mode across all regions, while North and South show the strongest demand for faster delivery options. This could help prioritize Express/Same-Day logistics capacity in high-volume regions.

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(
    shipping_region,
    annot=True,
    fmt="d",
    cmap="YlGnBu"
)

plt.title("Shipping Mode Usage by Region")
plt.xlabel("Shipping Mode")
plt.ylabel("Region")

plt.tight_layout()
plt.show()

# %%
region_category = pd.pivot_table(
    df,
    values="Realized_Sales_INR",
    index="Region",
    columns="Category",
    aggfunc="sum"
)

print(region_category.round(2))
# Out:
# Category   Automotive     Beauty      Books  Electronics     Fashion  \
# Region
# Central     885055.08  397412.29  306216.34  11762752.78  1101750.58
# East       1614837.84  501035.38  435823.79  16293562.93  1545275.53
# North      2632400.98  924792.48  659506.97  31680114.16  2838307.90
# Northeast   597517.40  198636.24  131990.39   5965216.05   586503.30
# South      2905608.34  925957.03  690414.31  27541483.88  2912441.02
# West       1924361.72  750569.66  519921.45  22805207.66  2401647.79
#
# Category    Furniture    Grocery  Home & Kitchen  Pet Supplies      Sports  \
# Region
# Central    2053571.62  164475.98      1788091.19     501176.46   848936.44
# East       2925629.45  221183.24      2554600.31     734179.56  1221366.18
# North      5015560.07  405721.84      4420512.08    1191064.57  1559712.20
# Northeast   849141.75   85600.33       957094.31     225032.78   587270.16
# South      4692389.42  433041.97      4250038.96    1208123.41  1949798.99
# ...

# %% [markdown]
# Business Insight
#
# Electronics is the leading category across all regions, with the North region generating the highest Electronics sales. This suggests that Electronics should remain a key category for regional growth strategies, particularly in North and South

# %%
plt.figure(figsize=(14, 6))

sns.heatmap(
    region_category,
    annot=True,
    fmt=".0f",
    cmap="YlGnBu"
)

plt.title("Category Sales by Region")
plt.xlabel("Category")
plt.ylabel("Region")

plt.tight_layout()
plt.show()

# %%
top_profit_products = df.groupby("Product_Name").agg(
    Total_Profit=("Profit_INR", "sum"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Orders=("Order_ID", "count")
).sort_values(
    "Total_Profit",
    ascending=False
).head(10)

print(top_profit_products.round(2))
# Out:
#                          Total_Profit  Total_Sales  Total_Orders
# Product_Name
# ApexBook 14 Laptop         7967405.15  73847062.45          1002
# Nova X5 Smartphone         4777661.45  31313275.14          1004
# Ergonomic Office Chair     3029494.81  12080419.06           962
# Digital Air Fryer          2648412.42   8758901.60          1039
# Smart Dash Camera          2169040.50   6975047.06          1008
# Modular Bookshelf          2143490.13   7734985.83          1006
# Adjustable Dumbbell Set    2110027.56   6026179.66           987
# Non-Stick Cookware Set     1967778.96   4431827.86           993
# Urban Running Shoes        1800300.73   4377212.75          1032
# FitPro Smartwatch          1751064.66   5598249.35          1003

# %%
plt.figure(figsize=(12, 6))

plt.bar(
    top_profit_products.index,
    top_profit_products["Total_Profit"]
)

plt.title("Top 10 Products by Profit")
plt.xlabel("Product Name")
plt.ylabel("Total Profit (INR)")

plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

bars = plt.bar(
    top_profit_products.index,
    top_profit_products["Total_Profit"]
)

plt.title("Top 10 Products by Profit")
plt.xlabel("Product Name")
plt.ylabel("Total Profit (₹)")

plt.xticks(rotation=45, ha="right")

# Profit values show karna
for bar in bars:
    value = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value,
        f"₹{value/100000:.1f}L",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %%
df["Discount_Group"] = pd.cut(
    df["Discount_Pct"],
    bins=[-1, 5, 10, 15, 20, 30, 100],
    labels=[
        "0-5%",
        "5-10%",
        "10-15%",
        "15-20%",
        "20-30%",
        "30%+"
    ]
)

print(df["Discount_Group"].value_counts().sort_index())
# Out:
# Discount_Group
# 0-5%      30000
# 5-10%         0
# 10-15%        0
# 15-20%        0
# 20-30%        0
# 30%+          0
# Name: count, dtype: int64

# %%
print(df["Discount_Pct"].describe())

print("\nUnique Discount Values:")
print(sorted(df["Discount_Pct"].unique())[:20])
# Out:
# count    30000.000000
# mean         0.105343
# std          0.061344
# min          0.000000
# 25%          0.050000
# 50%          0.100000
# 75%          0.150000
# max          0.250000
# Name: Discount_Pct, dtype: float64
#
# Unique Discount Values:
# [np.float64(0.0), np.float64(0.05), np.float64(0.1), np.float64(0.15), np.float64(0.2), np.float64(0.25)]

# %%
df["Discount_Group"] = pd.cut(
    df["Discount_Pct"],
    bins=[-0.001, 0.05, 0.10, 0.15, 0.20, 0.25],
    labels=[
        "0-5%",
        "5-10%",
        "10-15%",
        "15-20%",
        "20-25%"
    ],
    include_lowest=True
)

print(df["Discount_Group"].value_counts().sort_index())
# Out:
# Discount_Group
# 0-5%      9777
# 5-10%     9658
# 10-15%    6318
# 15-20%    3381
# 20-25%     866
# Name: count, dtype: int64

# %%
discount_analysis = df.groupby("Discount_Group", observed=True).agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum")
)

discount_analysis["Profit_Margin_%"] = (
    discount_analysis["Total_Profit"] /
    discount_analysis["Total_Sales"] * 100
)

print(discount_analysis.round(2))
# Out:
#                 Total_Orders  Total_Sales  Total_Profit  Profit_Margin_%
# Discount_Group
# 0-5%                    9777  72223309.76   20952667.58            29.01
# 5-10%                   9658  66228417.29   15999682.71            24.16
# 10-15%                  6318  38480358.98    7773757.13            20.20
# 15-20%                  3381  19185067.01    2943302.25            15.34
# 20-25%                   866   5293654.70     421482.28             7.96

# %% [markdown]
# Business Recommendation: High discounts ko selectively use karna better hoga, especially un products/categories par jahan margin already low hai.

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    discount_analysis.index.astype(str),
    discount_analysis["Profit_Margin_%"]
)

plt.title("Discount vs Profit Margin")
plt.xlabel("Discount Group")
plt.ylabel("Profit Margin (%)")

plt.tight_layout()
plt.show()

# %%
discount_return = df.groupby("Discount_Group", observed=True).agg(
    Total_Orders=("Order_ID", "count"),
    Returned_Orders=("Return_Flag", lambda x: (x == "Yes").sum())
)

discount_return["Return_Rate_%"] = (
    discount_return["Returned_Orders"] /
    discount_return["Total_Orders"] * 100
)

print(discount_return.round(2))
# Out:
#                 Total_Orders  Returned_Orders  Return_Rate_%
# Discount_Group
# 0-5%                    9777              463           4.74
# 5-10%                   9658              479           4.96
# 10-15%                  6318              286           4.53
# 15-20%                  3381              150           4.44
# 20-25%                   866               49           5.66

# %% [markdown]
# Business Insight: Very high discounts may attract more return-prone purchases, so discounts above 20% should be monitored carefully.

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    discount_return.index.astype(str),
    discount_return["Return_Rate_%"]
)

plt.title("Discount vs Return Rate")
plt.xlabel("Discount Group")
plt.ylabel("Return Rate (%)")

plt.tight_layout()
plt.show()

# %%
rating_analysis = df.groupby("Customer_Rating").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum")
)

rating_analysis["Profit_Margin_%"] = (
    rating_analysis["Total_Profit"] /
    rating_analysis["Total_Sales"] * 100
)

print(rating_analysis.round(2))
# Out:
#                  Total_Orders  Total_Sales  Total_Profit  Profit_Margin_%
# Customer_Rating
# 1.0                      1369   6044727.19    1388411.66            22.97
# 2.0                      2129  10476454.83    2642484.70            25.22
# 3.0                      4956  34808557.76    8266093.42            23.75
# 4.0                     11254  81361998.48   19605682.12            24.10
# 5.0                      8285  63445605.93   14892013.07            23.47

# %% [markdown]
# Project Insight
#
# Customers/orders with a 4-star rating contribute the highest sales volume, while the highest profit margin occurs at 2 stars. Therefore, customer rating alone does not appear to be a direct driver of profitability.

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    rating_analysis.index.astype(str),
    rating_analysis["Total_Sales"]
)

plt.title("Customer Rating vs Total Sales")
plt.xlabel("Customer Rating")
plt.ylabel("Total Sales (₹)")

plt.tight_layout()
plt.show()

# %%
profit_analysis = {
    "Total_Orders": len(df),
    "Profitable_Orders": (df["Profit_INR"] > 0).sum(),
    "Loss_Making_Orders": (df["Profit_INR"] < 0).sum(),
    "Zero_Profit_Orders": (df["Profit_INR"] == 0).sum()
}

print(profit_analysis)
# Out:
# {'Total_Orders': 30000, 'Profitable_Orders': np.int64(27241), 'Loss_Making_Orders': np.int64(544), 'Zero_Profit_Orders': np.int64(2215)}

# %% [markdown]
# Business Insight
#
# The business is largely profitable, with 90.8% of orders generating positive profit. However, 9.2% of orders generate zero or negative profit, indicating an opportunity to optimize pricing, discounts, costs, and returns.

# %%
loss_category = df[df["Profit_INR"] < 0].groupby("Category").agg(
    Loss_Making_Orders=("Order_ID", "count"),
    Total_Loss=("Profit_INR", "sum")
).sort_values(
    "Total_Loss"
)

print(loss_category.round(2))
# Out:
#                 Loss_Making_Orders  Total_Loss
# Category
# Electronics                    182  -161005.66
# Home & Kitchen                  61    -6839.00
# Fashion                         59    -6641.00
# Books                           33    -3867.00
# Sports                          34    -3616.00
# Beauty                          30    -3420.00
# Grocery                         46    -3414.44
# Pet Supplies                    29    -3121.00
# Furniture                       28    -3072.00
# Automotive                      23    -2777.00
# Toys                            19    -2281.00

# %% [markdown]
#   Business Insight
#
# Electronics is the major source of losses, contributing ₹1.61 lakh in total losses across 182 orders. This category should be investigated for pricing, discounting, product costs, and returns.

# %%
loss_discount = df[df["Profit_INR"] < 0].groupby("Discount_Group").agg(
    Loss_Making_Orders=("Order_ID", "count"),
    Total_Loss=("Profit_INR", "sum")
).sort_values(
    "Total_Loss"
)

print(loss_discount.round(2))
# Out:
#                 Loss_Making_Orders  Total_Loss
# Discount_Group
# 20-25%                          83  -152998.27
# 5-10%                          151   -16999.00
# 0-5%                           130   -14320.00
# 10-15%                          82    -8837.80
# 15-20%                          98    -6899.04

# %% [markdown]
# Final Business Recommendation
#
# High discounts, particularly 20–25%, should be used selectively because they significantly reduce profit margins and account for a disproportionate share of total losses.

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    loss_discount.index.astype(str),
    loss_discount["Total_Loss"].abs()
)

plt.title("Loss-Making Orders by Discount Group")
plt.xlabel("Discount Group")
plt.ylabel("Total Loss (₹)")

plt.tight_layout()
plt.show()

# %%
category_margin = df.groupby("Category").agg(
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Orders=("Order_ID", "count")
)

category_margin["Profit_Margin_%"] = (
    category_margin["Total_Profit"] /
    category_margin["Total_Sales"] * 100
)

category_margin = category_margin.sort_values(
    "Profit_Margin_%",
    ascending=False
)

print(category_margin.round(2))
# Out:
#                  Total_Sales  Total_Profit  Total_Orders  Profit_Margin_%
# Category
# Beauty          3.698403e+06    2096495.98          3068            56.69
# Books           2.743873e+06    1268049.96          1932            46.21
# Fashion         1.138593e+07    5233231.91          4044            45.96
# Toys            5.429559e+06    2398466.88          2018            44.17
# Home & Kitchen  1.748387e+07    6759708.74          4072            38.66
# Sports          7.619502e+06    2943538.77          2002            38.63
# Pet Supplies    4.948905e+06    1696635.62          1913            34.28
# Automotive      1.055978e+07    3557936.10          2021            33.69
# Grocery         1.677245e+06     450663.37          1929            26.87
# Furniture       1.981540e+07    5172984.94          1968            26.11
# Electronics     1.160483e+08   16513179.67          5033            14.23

# %% [markdown]
# Electronics generates the highest sales but has the lowest profit margin, while Beauty generates much lower sales but achieves the highest margin. This indicates an opportunity to improve Electronics pricing, costs, or discount strategy.

# %%
plt.figure(figsize=(12, 6))

bars = plt.bar(
    category_margin.index,
    category_margin["Profit_Margin_%"]
)

plt.title("Profit Margin by Category")
plt.xlabel("Category")
plt.ylabel("Profit Margin (%)")

plt.xticks(rotation=45, ha="right")

for bar in bars:
    value = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value,
        f"{value:.1f}%",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %%
total_orders = len(df)

total_sales = df["Realized_Sales_INR"].sum()
total_profit = df["Profit_INR"].sum()
total_refund = df["Refund_Amount_INR"].sum()

profit_margin = (total_profit / total_sales) * 100

returned_orders = (df["Return_Flag"] == "Yes").sum()
return_rate = (returned_orders / total_orders) * 100

avg_order_value = total_sales / total_orders

print("========== E-COMMERCE KPI ==========")
print(f"Total Orders       : {total_orders:,}")
print(f"Total Sales        : ₹{total_sales:,.2f}")
print(f"Total Profit       : ₹{total_profit:,.2f}")
print(f"Total Refund       : ₹{total_refund:,.2f}")
print(f"Profit Margin      : {profit_margin:.2f}%")
print(f"Returned Orders    : {returned_orders:,}")
print(f"Return Rate        : {return_rate:.2f}%")
print(f"Average Order Value: ₹{avg_order_value:,.2f}")
# Out:
# ========== E-COMMERCE KPI ==========
# Total Orders       : 30,000
# Total Sales        : ₹201,410,807.72
# Total Profit       : ₹48,090,891.94
# Total Refund       : ₹10,705,212.31
# Profit Margin      : 23.88%
# Returned Orders    : 1,427
# Return Rate        : 4.76%
# Average Order Value: ₹6,713.69

# %%
plt.figure(figsize=(14, 6))

# Using the correct variable name 'monthly_sales' defined in previous steps
plt.plot(
    monthly_sales.index.astype(str),
    monthly_sales["Total_Sales"],
    marker="o",
    label="Total Sales"
)

plt.plot(
    monthly_sales.index.astype(str),
    monthly_sales["Total_Profit"],
    marker="o",
    label="Total Profit"
)

plt.title("Monthly Sales and Profit Trend")
plt.xlabel("Month")
plt.ylabel("Amount (₹)")

plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %%
category_performance = df.groupby("Category").agg(
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum"),
    Total_Orders=("Order_ID", "count")
)

category_performance["Profit_Margin_%"] = (
    category_performance["Total_Profit"] /
    category_performance["Total_Sales"] * 100
)

category_performance = category_performance.sort_values(
    "Total_Profit",
    ascending=False
)

print(category_performance.round(2))
# Out:
#                  Total_Sales  Total_Profit  Total_Orders  Profit_Margin_%
# Category
# Electronics     1.160483e+08   16513179.67          5033            14.23
# Home & Kitchen  1.748387e+07    6759708.74          4072            38.66
# Fashion         1.138593e+07    5233231.91          4044            45.96
# Furniture       1.981540e+07    5172984.94          1968            26.11
# Automotive      1.055978e+07    3557936.10          2021            33.69
# Sports          7.619502e+06    2943538.77          2002            38.63
# Toys            5.429559e+06    2398466.88          2018            44.17
# Beauty          3.698403e+06    2096495.98          3068            56.69
# Pet Supplies    4.948905e+06    1696635.62          1913            34.28
# Books           2.743873e+06    1268049.96          1932            46.21
# Grocery         1.677245e+06     450663.37          1929            26.87

# %% [markdown]
# Important project insight
#
# Electronics is the biggest revenue and profit contributor, but its 14.23% profit margin is significantly lower than other categories. Therefore, improving pricing, product costs, and discount strategy in Electronics could have a major impact on overall profitability.

# %% [markdown]
# 10 major insights
#
# 1️⃣ Overall Business
#
# 30,000 orders generated ₹20.14 Cr sales and ₹4.81 Cr profit, with an overall 23.88% profit margin.
#
# 2️⃣ Monthly Performance
#
# October 2025 was the strongest month with approximately ₹1.63 Cr sales and ₹30.99 Lakh profit.
#
# 3️⃣ Customer Segment
#
# Consumer segment dominates with 71.84% of customers/orders and contributes the highest sales and profit.
#
# 4️⃣ Customer Type
#
# Returning customers contribute slightly higher sales (₹10.37 Cr) than new customers (₹9.77 Cr).
#
# 5️⃣ Geography
#
# North region generates the highest sales (₹5.27 Cr), while South has the highest order volume.
#
# 6️⃣ Product
#
# ApexBook 14 Laptop is the strongest product by sales, generating approximately ₹7.38 Cr.
#
# 7️⃣ Sales Channel
#
# Mobile App is the dominant channel with 51.31% of orders and approximately ₹10.51 Cr sales.
#
# 8️⃣ Traffic Source
#
# Organic Search brings the highest number of orders (7,985) and highest sales (₹5.36 Cr).
#
# 9️⃣ Discount Strategy
#
# Profitability falls sharply as discounts increase:
#
# 0–5% → 29.01% margin
# 20–25% → only 7.96% margin
#
# Also, the 20–25% discount group accounts for a disproportionately large amount of loss.
#
# 🔟 Category Profitability
#
# Electronics generates the most sales and profit but has only 14.23% margin, while Beauty has the highest margin at 56.69%.

# %%
# !pip install -q openai

# %%
from google.colab import userdata

OPENAI_API_KEY = userdata.get("OPENAI_API_KEY")

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
from openai import OpenAI
from google.colab import userdata

OPENAI_API_KEY = userdata.get("OPENAI_API_KEY")

client = OpenAI(api_key=OPENAI_API_KEY)

print("GenAI connection setup successful!")
# Out:
# GenAI connection setup successful!

# %%
import torch

print("GPU Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU: Tesla T4

# %%
# !pip install -q transformers accelerate bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 21.9 MB/s eta 0:00:00

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "Qwen/Qwen2.5-3B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)

print("GenAI model loaded successfully!")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/35.6k [00:00<?, ?B/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# ...
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# GenAI model loaded successfully!

# %%
prompt = """
You are a senior e-commerce data analyst.

Analyze these business results:

Total Orders: 30,000
Total Sales: ₹201,410,807.72
Total Profit: ₹48,090,891.94
Profit Margin: 23.88%
Total Refund: ₹10,705,212.31
Returned Orders: 1,427
Return Rate: 4.76%
Average Order Value: ₹6,713.69

Category Performance:
Electronics - Sales: ₹116,048,300, Profit Margin: 14.23%
Beauty - Sales: ₹3,698,403, Profit Margin: 56.69%
Home & Kitchen - Sales: ₹17,483,870, Profit Margin: 38.66%
Fashion - Sales: ₹11,385,930, Profit Margin: 45.96%

Discount Performance:
0-5% discount - Profit Margin: 29.01%
5-10% discount - Profit Margin: 24.16%
10-15% discount - Profit Margin: 20.20%
15-20% discount - Profit Margin: 15.34%
20-25% discount - Profit Margin: 7.96%

Loss Analysis:
20-25% discount group had 83 loss-making orders
Total loss from this group: ₹152,998.27

Sales Channel:
Mobile App - 51.31% of orders
Website - 33.46%
Marketplace - 15.23%

Traffic Source:
Organic Search - 7,985 orders
Social Media - 6,343 orders
Paid Search - 5,768 orders

Based ONLY on this information:

1. Give 5 key business insights.
2. Identify 3 business problems.
3. Give 5 practical recommendations.
4. Write a short management summary.

Do not invent any data.
"""

messages = [
    {
        "role": "user",
        "content": prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=700,
        temperature=0.7,
        do_sample=True
    )

response = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(response)
# Out:
# ### Key Business Insights
#
# 1. **High Profit Margins for Specific Categories:** The Beauty and Fashion categories have the highest profit margins, indicating that these products may be high-margin items or require higher pricing strategies to achieve these margins. This suggests a strong focus on these categories could drive profitability.
#
# 2. **Significant Refunds and Return Rates:** With 1,427 returned orders and a return rate of 4.76%, there is significant room for improvement in order accuracy and customer satisfaction, particularly with Electronics and Home & Kitchen categories which have higher return rates.
#
# 3. **Strong Mobile App Performance:** The Mobile App accounts for 51.31% of total orders, highlighting its importance as a primary sales channel. However, the lower website performance (33.46%) could indicate potential opportunities for digital marketing efforts to boost website traffic and conversions.
#
# ...

# %%
import pandas as pd

df = pd.read_csv(
    "/content/recent_ecommerce_sales_dataset_2025_2026_30000_rows (1).csv"
)

print("Data loaded successfully!")
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Data loaded successfully!
# Rows: 30000
# Columns: 38

# %%
total_orders = len(df)

total_sales = df["Realized_Sales_INR"].sum()
total_profit = df["Profit_INR"].sum()
total_refund = df["Refund_Amount_INR"].sum()

profit_margin = (total_profit / total_sales) * 100

returned_orders = (df["Return_Flag"] == "Yes").sum()
return_rate = (returned_orders / total_orders) * 100

avg_order_value = total_sales / total_orders

print("KPI variables ready!")
# Out:
# KPI variables ready!

# %%
verified_data = {
    "Total Orders": int(total_orders),
    "Total Sales": float(total_sales),
    "Total Profit": float(total_profit),
    "Total Refund": float(total_refund),
    "Profit Margin %": float(profit_margin),
    "Returned Orders": int(returned_orders),
    "Return Rate %": float(return_rate),
    "Average Order Value": float(avg_order_value)
}

print(verified_data)
# Out:
# {'Total Orders': 30000, 'Total Sales': 201410807.72499996, 'Total Profit': 48090891.935, 'Total Refund': 10705212.315, 'Profit Margin %': 23.8770165703629, 'Returned Orders': 1427, 'Return Rate %': 4.756666666666667, 'Average Order Value': 6713.693590833333}

# %%
verified_summary = f"""
E-COMMERCE BUSINESS KPI

Total Orders: {total_orders:,}
Total Sales: ₹{total_sales:,.2f}
Total Profit: ₹{total_profit:,.2f}
Total Refund: ₹{total_refund:,.2f}
Profit Margin: {profit_margin:.2f}%
Returned Orders: {returned_orders:,}
Return Rate: {return_rate:.2f}%
Average Order Value: ₹{avg_order_value:,.2f}
"""

print(verified_summary)
# Out:
# E-COMMERCE BUSINESS KPI
#
# Total Orders: 30,000
# Total Sales: ₹201,410,807.72
# Total Profit: ₹48,090,891.94
# Total Refund: ₹10,705,212.31
# Profit Margin: 23.88%
# Returned Orders: 1,427
# Return Rate: 4.76%
# Average Order Value: ₹6,713.69

# %%
messages = [
    {
        "role": "system",
        "content": """
You are an e-commerce business analyst.

Analyze ONLY the data provided by the user.

Strict rules:
- Do not invent numbers.
- Do not assume missing information.
- Do not claim a category has a high/low return rate unless return-rate data is provided.
- Keep all currency values in Indian Rupees (₹).
- Clearly say when information is not available.
- Give actionable business recommendations based only on the available data.
"""
    },
    {
        "role": "user",
        "content": f"""
Analyze the following verified e-commerce KPIs:

{verified_summary}

Provide:

1. Key Business Insights
   - Give 5 insights.

2. Business Problems
   - Give 3 problems supported by the data.

3. Recommendations
   - Give 5 practical recommendations.

4. Management Summary
   - Write a concise professional summary suitable for a Data Analyst project.

Use the exact numbers where relevant.
"""
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=800,
        temperature=0.3,
        do_sample=True
    )

ai_insight = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(ai_insight)
# Out:
# ### 1. Key Business Insights
#
# 1. **High Profit Margin**: The profit margin of 23.88% indicates that the business is efficiently managing its costs and pricing strategy.
# 2. **Significant Return Rate**: With a return rate of 4.76%, there is room to improve customer satisfaction and reduce returns.
# 3. **Moderate Average Order Value**: The average order value of ₹6,713.69 suggests that the product mix or pricing strategy could be adjusted to attract customers with higher average spend.
# 4. **Positive Total Sales**: Despite some refunds, total sales amount to ₹201,410,807.72, indicating strong demand for products.
# 5. **Proportion of Returned Orders**: Out of 30,000 orders, 1,427 were returned, which equates to about 0.477% of total orders, suggesting that while returns are significant, they do not significantly impact overall sales.
#
# ### 2. Business Problems
#
# ...

# %%
validation_prompt = f"""
You are a senior e-commerce data analyst.

Use ONLY the verified data below.

{verified_summary}

Before writing the final answer:
- Recalculate every percentage yourself.
- Check that Returned Orders / Total Orders × 100 equals Return Rate.
- Never change ₹ to $.
- Never invent missing information.
- If a calculation conflicts with the supplied KPI, use the mathematically correct calculation.

Now provide:

1. 5 verified business insights
2. 3 data-supported business problems
3. 5 practical recommendations
4. A concise management summary

For every numerical claim, ensure it is consistent with the verified data.
"""

messages = [
    {
        "role": "system",
        "content": "You are a careful data analyst. Accuracy is more important than generating assumptions."
    },
    {
        "role": "user",
        "content": validation_prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=800,
        temperature=0.2,
        do_sample=True
    )

validated_ai_insight = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(validated_ai_insight)
# Out:
# ### 1. Verified Business Insights
#
# 1. **High Profit Margin**: The profit margin of 23.88% indicates that for every ₹100 in sales, the company retains ₹23.88 as profit. This suggests strong operational efficiency and pricing strategies.
#
# 2. **Significant Sales Volume**: With 30,000 total orders, the company is handling a substantial volume of transactions, which can be leveraged for marketing and customer acquisition efforts.
#
# 3. **Moderate Return Rate**: The return rate of 4.76% is relatively low compared to industry averages, indicating that customers are generally satisfied with their purchases, which can reduce operational costs associated with returns.
#
# 4. **Strong Average Order Value (AOV)**: The average order value of ₹6,713.69 is high, suggesting that each order contributes significantly to the overall revenue, which can be beneficial for upselling and cross-selling opportunities.
#
# ...

# %% [markdown]
# "I used Python for numerical accuracy and an open-source LLM for natural-language business interpretation. The LLM was grounded on verified analytical outputs to reduce hallucinations."

# %%
category_analysis = df.groupby("Category").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Sales=("Realized_Sales_INR", "sum"),
    Total_Profit=("Profit_INR", "sum")
)

category_analysis["Profit_Margin_%"] = (
    category_analysis["Total_Profit"] /
    category_analysis["Total_Sales"] * 100
)

category_analysis = category_analysis.sort_values(
    "Total_Sales",
    ascending=False
)

print(category_analysis.round(2))
# Out:
#                 Total_Orders   Total_Sales  Total_Profit  Profit_Margin_%
# Category
# Electronics             5033  1.160483e+08   16513179.67            14.23
# Furniture               1968  1.981540e+07    5172984.94            26.11
# Home & Kitchen          4072  1.748387e+07    6759708.74            38.66
# Fashion                 4044  1.138593e+07    5233231.91            45.96
# Automotive              2021  1.055978e+07    3557936.10            33.69
# Sports                  2002  7.619502e+06    2943538.77            38.63
# Toys                    2018  5.429559e+06    2398466.88            44.17
# Pet Supplies            1913  4.948905e+06    1696635.62            34.28
# Beauty                  3068  3.698403e+06    2096495.98            56.69
# Books                   1932  2.743873e+06    1268049.96            46.21
# Grocery                 1929  1.677245e+06     450663.37            26.87

# %%
category_text = category_analysis.round(2).to_string()

print(category_text)
# Out:
#                 Total_Orders   Total_Sales  Total_Profit  Profit_Margin_%
# Category
# Electronics             5033  1.160483e+08   16513179.67            14.23
# Furniture               1968  1.981540e+07    5172984.94            26.11
# Home & Kitchen          4072  1.748387e+07    6759708.74            38.66
# Fashion                 4044  1.138593e+07    5233231.91            45.96
# Automotive              2021  1.055978e+07    3557936.10            33.69
# Sports                  2002  7.619502e+06    2943538.77            38.63
# Toys                    2018  5.429559e+06    2398466.88            44.17
# Pet Supplies            1913  4.948905e+06    1696635.62            34.28
# Beauty                  3068  3.698403e+06    2096495.98            56.69
# Books                   1932  2.743873e+06    1268049.96            46.21
# Grocery                 1929  1.677245e+06     450663.37            26.87

# %%
category_prompt = f"""
You are a senior e-commerce data analyst.

Analyze ONLY the verified data provided below.

OVERALL KPIs:
{verified_summary}

CATEGORY PERFORMANCE:
{category_text}

Strict rules:
- Do not invent any numbers.
- Do not use external industry benchmarks.
- Do not make claims about information that is not present.
- Keep currency in Indian Rupees (₹).
- Compare categories using the provided data only.

Give the following:

1. Top 3 categories by Total Sales.
2. Top 3 categories by Total Profit.
3. Top 3 categories by Profit Margin.
4. Identify the category with the biggest business concern and explain why.
5. Give 5 actionable recommendations.
6. Write a short management summary.

Use exact numbers from the data where relevant.
"""

messages = [
    {
        "role": "system",
        "content": """
You are a data-grounded e-commerce analyst.
Your priority is numerical accuracy.
Never invent or assume missing information.
"""
    },
    {
        "role": "user",
        "content": category_prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=900,
        temperature=0.2,
        do_sample=True
    )

category_ai_analysis = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(category_ai_analysis)
# Out:
# ### Analysis Based on Provided Data
#
# #### 1. Top 3 Categories by Total Sales
# 1. **Beauty** - ₹3,698,403,000.00
# 2. **Books** - ₹2,743,873,000.00
# 3. **Electronics** - ₹1,160,483,000.00
#
# #### 2. Top 3 Categories by Total Profit
# 1. **Beauty** - ₹2,096,495.98
# 2. **Books** - ₹1,268,049.96
# 3. **Electronics** - ₹1,651,317,967.00
#
# #### 3. Top 3 Categories by Profit Margin
# 1. **Beauty** - 56.69%
# 2. **Books** - 46.21%
# 3. **Electronics** - 14.23%
#
# #### 4. Category with the Biggest Business Concern and Explanation
# The category with the biggest business concern is **Grocery**. This can be inferred from the low Total Sales of ₹16,772,450,000.00 and the relatively low Total Profit of ₹450,663.37. The low profit margin of 26.87% also indicates poor profitability. Additionally, the Return Rate of 29.43% suggests a high level of customer dissatisfaction or issues with product quality/availability, which could be impacting sales and profits negatively.
#
# ...

# %%
top_sales = category_analysis.nlargest(3, "Total_Sales")

top_profit = category_analysis.nlargest(3, "Total_Profit")

top_margin = category_analysis.nlargest(3, "Profit_Margin_%")

print("===== TOP 3 BY SALES =====")
print(top_sales[["Total_Sales"]].round(2))

print("\n===== TOP 3 BY PROFIT =====")
print(top_profit[["Total_Profit"]].round(2))

print("\n===== TOP 3 BY PROFIT MARGIN =====")
print(top_margin[["Profit_Margin_%"]].round(2))
# Out:
# ===== TOP 3 BY SALES =====
#                  Total_Sales
# Category
# Electronics     1.160483e+08
# Furniture       1.981540e+07
# Home & Kitchen  1.748387e+07
#
# ===== TOP 3 BY PROFIT =====
#                 Total_Profit
# Category
# Electronics      16513179.67
# Home & Kitchen    6759708.74
# Fashion           5233231.91
#
# ===== TOP 3 BY PROFIT MARGIN =====
#           Profit_Margin_%
# Category
# Beauty              56.69
# Books               46.21
# Fashion             45.96

# %%
validated_category_data = f"""
OVERALL BUSINESS KPI:
{verified_summary}

TOP 3 CATEGORIES BY SALES:
{top_sales[["Total_Sales"]].round(2).to_string()}

TOP 3 CATEGORIES BY PROFIT:
{top_profit[["Total_Profit"]].round(2).to_string()}

TOP 3 CATEGORIES BY PROFIT MARGIN:
{top_margin[["Profit_Margin_%"]].round(2).to_string()}
"""

print(validated_category_data)
# Out:
# OVERALL BUSINESS KPI:
#
# E-COMMERCE BUSINESS KPI
#
# Total Orders: 30,000
# Total Sales: ₹201,410,807.72
# Total Profit: ₹48,090,891.94
# Total Refund: ₹10,705,212.31
# Profit Margin: 23.88%
# Returned Orders: 1,427
# Return Rate: 4.76%
# Average Order Value: ₹6,713.69
#
#
# TOP 3 CATEGORIES BY SALES:
#                  Total_Sales
# Category
# Electronics     1.160483e+08
# Furniture       1.981540e+07
# Home & Kitchen  1.748387e+07
#
# TOP 3 CATEGORIES BY PROFIT:
#                 Total_Profit
# Category
# Electronics      16513179.67
# Home & Kitchen    6759708.74
# Fashion           5233231.91
#
# TOP 3 CATEGORIES BY PROFIT MARGIN:
#           Profit_Margin_%
# Category
# Beauty              56.69
# Books               46.21
# Fashion             45.96

# %%
final_prompt = f"""
You are a senior e-commerce business analyst.

Below is VERIFIED analytical output generated by Python.

{validated_category_data}

Your job is ONLY to interpret this verified information.

STRICT RULES:
1. Do not calculate new numerical values.
2. Do not change any existing numbers.
3. Do not invent return rates, industry benchmarks, customer behavior,
   or information that is not provided.
4. Keep all currency values in Indian Rupees (₹).
5. If information is unavailable, explicitly say:
   "This information is not available in the provided analysis."
6. Do not create rankings that are not already provided.
7. Recommendations must be based only on the provided data.

Generate a professional report with:

### 1. Key Business Insights
Give 5 insights based strictly on the verified data.

### 2. Business Problems
Identify 3 business problems that can genuinely be supported
by the provided numbers.

### 3. Practical Recommendations
Give 5 actionable recommendations.

### 4. Management Summary
Write a concise professional summary suitable for a
Data Analyst portfolio project.

Make the report clear, concise and business-oriented.
"""

messages = [
    {
        "role": "system",
        "content": """
You are a grounded business intelligence analyst.
Never hallucinate data.
Never invent missing metrics.
Interpret only verified Python-generated results.
"""
    },
    {
        "role": "user",
        "content": final_prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=1000,
        temperature=0.1,
        do_sample=True
    )

final_ai_report = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(final_ai_report)
# Out:
# ### 1. Key Business Insights
#
# 1. **High Profit Margin in Electronics:** The category of Electronics has the highest profit margin at 56.69%, indicating strong profitability.
# 2. **Significant Sales Volume in Furniture and Home & Kitchen:** These categories collectively account for over 18 million rupees in sales, suggesting they are key revenue drivers.
# 3. **High Return Rate:** The return rate of 4.76% indicates that a significant portion of orders are being returned, which could be an area for improvement.
# 4. **Strong Sales Performance in Fashion Category:** Despite having a lower profit margin compared to Electronics, the fashion category still generates substantial sales.
# 5. **Declining Sales in Furniture Category:** The sales volume in Furniture has decreased significantly, which may require attention to maintain market share.
#
# ### 2. Business Problems
#
# ...

# %%
# Ground-truth values from Python
ground_truth = {
    "top_sales": top_sales.index.tolist(),
    "top_profit": top_profit.index.tolist(),
    "top_margin": top_margin.index.tolist(),
    "beauty_margin": category_analysis.loc["Beauty", "Profit_Margin_%"],
    "electronics_margin": category_analysis.loc["Electronics", "Profit_Margin_%"],
    "return_rate": return_rate
}

print("===== GROUND TRUTH =====")
print("Top Sales:", ground_truth["top_sales"])
print("Top Profit:", ground_truth["top_profit"])
print("Top Margin:", ground_truth["top_margin"])
print("Beauty Margin:", ground_truth["beauty_margin"])
print("Electronics Margin:", ground_truth["electronics_margin"])
print("Return Rate:", ground_truth["return_rate"])
# Out:
# ===== GROUND TRUTH =====
# Top Sales: ['Electronics', 'Furniture', 'Home & Kitchen']
# Top Profit: ['Electronics', 'Home & Kitchen', 'Fashion']
# Top Margin: ['Beauty', 'Books', 'Fashion']
# Beauty Margin: 56.68651921517459
# Electronics Margin: 14.229570223190175
# Return Rate: 4.756666666666667

# %%
validation_results = {
    "Electronics is Top Sales Category":
        ground_truth["top_sales"][0] == "Electronics",

    "Electronics is Top Profit Category":
        ground_truth["top_profit"][0] == "Electronics",

    "Beauty is Top Margin Category":
        ground_truth["top_margin"][0] == "Beauty",

    "Electronics Margin is 14.23%":
        round(ground_truth["electronics_margin"], 2) == 14.23,

    "Beauty Margin is 56.69%":
        round(ground_truth["beauty_margin"], 2) == 56.69,

    "Return Rate is 4.76%":
        round(ground_truth["return_rate"], 2) == 4.76
}

print("===== GENAI FACT VALIDATION =====")

for check, result in validation_results.items():
    status = "PASS" if result else "FAIL"
    print(f"{status}: {check}")

print("\nOverall Validation:",
      "PASSED" if all(validation_results.values()) else "FAILED")
# Out:
# ===== GENAI FACT VALIDATION =====
# PASS: Electronics is Top Sales Category
# PASS: Electronics is Top Profit Category
# PASS: Beauty is Top Margin Category
# PASS: Electronics Margin is 14.23%
# PASS: Beauty Margin is 56.69%
# PASS: Return Rate is 4.76%
#
# Overall Validation: PASSED

# %%
report_text = final_ai_report.lower()

checks = {
    "Electronics mentioned as top sales":
        "electronics" in report_text,

    "Electronics mentioned as top profit":
        "electronics" in report_text,

    "Beauty mentioned as top margin":
        "beauty" in report_text,

    "Correct Electronics margin mentioned":
        "14.23" in report_text,

    "Correct Beauty margin mentioned":
        "56.69" in report_text,

    "Correct Return Rate mentioned":
        "4.76" in report_text,

    "Incorrect Electronics margin NOT mentioned":
        "electronics" not in report_text or "56.69%" not in report_text
}

print("===== ACTUAL GENAI REPORT VALIDATION =====")

for check, result in checks.items():
    print(f"{'PASS' if result else 'FAIL'}: {check}")

print(
    "\nOverall Report Validation:",
    "PASSED" if all(checks.values()) else "NEEDS REVIEW"
)
# Out:
# ===== ACTUAL GENAI REPORT VALIDATION =====
# PASS: Electronics mentioned as top sales
# PASS: Electronics mentioned as top profit
# FAIL: Beauty mentioned as top margin
# FAIL: Correct Electronics margin mentioned
# PASS: Correct Beauty margin mentioned
# PASS: Correct Return Rate mentioned
# FAIL: Incorrect Electronics margin NOT mentioned
#
# Overall Report Validation: NEEDS REVIEW

# %%
correction_prompt = f"""
You are a senior e-commerce data analyst.

IMPORTANT:
The following information is the VERIFIED GROUND TRUTH calculated by Python.
You MUST follow it exactly.

===== VERIFIED GROUND TRUTH =====

Top 3 Sales Categories:
1. Electronics
2. Furniture
3. Home & Kitchen

Top 3 Profit Categories:
1. Electronics
2. Home & Kitchen
3. Fashion

Top 3 Profit Margin Categories:
1. Beauty - 56.69%
2. Books - 46.21%
3. Fashion - 45.96%

Electronics Profit Margin: 14.23%
Beauty Profit Margin: 56.69%

Overall Return Rate: 4.76%

Overall KPIs:
{verified_summary}

===== STRICT RULES =====

- Electronics profit margin is 14.23%, NOT 56.69%.
- Beauty profit margin is 56.69%.
- Do not say Furniture sales are declining because no time-series data is provided.
- Do not say Home & Kitchen has low sales because it is #3 in sales.
- Do not invent return rates for individual categories.
- Do not use external industry benchmarks.
- Do not invent any numerical values.
- Currency must remain ₹.
- Only make claims supported by the verified ground truth.

Now generate:

1. Five accurate business insights.
2. Three data-supported business problems.
3. Five practical recommendations.
4. A professional management summary.

Before finalizing your answer, internally check every numerical statement
against the verified ground truth.
"""

messages = [
    {
        "role": "system",
        "content": """
You are a highly accurate, data-grounded business analyst.
Python-generated ground truth has higher priority than your assumptions.
Never contradict verified values.
"""
    },
    {
        "role": "user",
        "content": correction_prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=1000,
        temperature=0.1,
        do_sample=True
    )

corrected_ai_report = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(corrected_ai_report)
# Out:
# ### Five Accurate Business Insights
#
# 1. **Electronics and Home & Kitchen lead in both sales and profit margins.** This indicates that these categories should be prioritized for further investment and marketing efforts to capitalize on their strong performance.
#
# 2. **Beauty products have the highest profit margin among all categories, at 56.69%.** This suggests that focusing on optimizing the Beauty category could significantly boost overall profitability.
#
# 3. **Fashion category has the second-highest profit margin (45.96%) but ranks third in sales.** This highlights the need to improve sales strategies for Fashion to match its high-profit potential.
#
# 4. **Home & Kitchen category has the highest sales volume but ranks second in profit margin.** This implies that while Home & Kitchen generates significant revenue, there's an opportunity to enhance profitability through cost optimization and better pricing strategies.
#
# ...

# %%
safe_prompt = f"""
You are an e-commerce business analyst.

You MUST treat the following Python-generated values as absolute facts.

===== VERIFIED FACTS =====

Overall:
- Total Orders: 30,000
- Total Sales: ₹201,410,807.72
- Total Profit: ₹48,090,891.94
- Profit Margin: 23.88%
- Total Refund: ₹10,705,212.31
- Returned Orders: 1,427
- Overall Return Rate: 4.76%
- Average Order Value: ₹6,713.69

Category Rankings:

TOP SALES:
1. Electronics
2. Furniture
3. Home & Kitchen

TOP PROFIT:
1. Electronics
2. Home & Kitchen
3. Fashion

TOP PROFIT MARGIN:
1. Beauty - 56.69%
2. Books - 46.21%
3. Fashion - 45.96%

Individual verified margins:
- Electronics: 14.23%
- Furniture: 26.11%
- Home & Kitchen: 38.66%
- Fashion: 45.96%
- Automotive: 33.69%
- Sports: 38.63%
- Toys: 44.17%
- Pet Supplies: 34.28%
- Beauty: 56.69%
- Books: 46.21%
- Grocery: 26.87%

===== ABSOLUTE RULES =====

1. Electronics is #1 in SALES.
2. Electronics is #1 in TOTAL PROFIT.
3. Beauty is #1 in PROFIT MARGIN.
4. Electronics profit margin is 14.23%.
5. Beauty profit margin is 56.69%.
6. Overall return rate is 4.76%.
7. 14.23% is NOT a return rate.
8. Do NOT assign the overall return rate to any category.
9. Do NOT claim sales are increasing or decreasing because no time-series
   category data has been provided.
10. Do NOT call Home & Kitchen the highest-sales category.
11. Do NOT call Electronics the highest-margin category.
12. Do NOT use external industry benchmarks.
13. Do not invent any numbers.
14. If information is unavailable, say so explicitly.

Generate ONLY:

1. Five accurate business insights.
2. Three data-supported business problems.
3. Five practical recommendations.
4. A concise management summary.

Every numerical statement must exactly match the verified facts above.
"""

messages = [
    {
        "role": "system",
        "content": """
You are a strict data-grounded business analyst.
Never contradict verified Python calculations.
Never infer missing metrics.
Numerical accuracy has highest priority.
"""
    },
    {
        "role": "user",
        "content": safe_prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=1000,
        temperature=0.0,
        do_sample=False
    )

safe_ai_report = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(safe_ai_report)
# Out:
# [transformers] The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ### Business Insights
#
# 1. **Electronics leads in both sales and total profit with ₹201,410,807.72 in total sales and ₹48,090,891.94 in total profit.**
# 2. **Beauty products have the highest profit margin at 56.69%, significantly outperforming other categories.**
# 3. **Home & Kitchen category ranks second in both sales and profit, contributing ₹20,141,080.77 in total sales and ₹19,235,447.72 in total profit.**
# 4. **Fashion category ranks third in sales and profit, contributing ₹10,070,521.23 in total sales and ₹10,045,447.72 in total profit.**
# 5. **The overall return rate stands at 4.76%, indicating that 4.76% of orders were returned.**
#
# ### Data-Supported Business Problems
#
# ...

# %%
safe_facts = f"""
VERIFIED BUSINESS FACTS

1. Electronics is the #1 category by Total Sales.
2. Furniture is #2 by Total Sales.
3. Home & Kitchen is #3 by Total Sales.

4. Electronics is the #1 category by Total Profit.
5. Home & Kitchen is #2 by Total Profit.
6. Fashion is #3 by Total Profit.

7. Beauty is the #1 category by Profit Margin at 56.69%.
8. Books is #2 by Profit Margin at 46.21%.
9. Fashion is #3 by Profit Margin at 45.96%.

10. Electronics Profit Margin is 14.23%.
11. Overall Return Rate is 4.76%.
12. Total Orders are 30,000.
"""

print(safe_facts)
# Out:
# VERIFIED BUSINESS FACTS
#
# 1. Electronics is the #1 category by Total Sales.
# 2. Furniture is #2 by Total Sales.
# 3. Home & Kitchen is #3 by Total Sales.
#
# 4. Electronics is the #1 category by Total Profit.
# 5. Home & Kitchen is #2 by Total Profit.
# 6. Fashion is #3 by Total Profit.
#
# 7. Beauty is the #1 category by Profit Margin at 56.69%.
# 8. Books is #2 by Profit Margin at 46.21%.
# 9. Fashion is #3 by Profit Margin at 45.96%.
#
# 10. Electronics Profit Margin is 14.23%.
# 11. Overall Return Rate is 4.76%.
# 12. Total Orders are 30,000.

# %%
safe_analysis_prompt = f"""
You are an e-commerce business analyst.

Use ONLY these verified facts:

{safe_facts}

Your task is to explain the business meaning of these facts.

STRICT RULES:
- Do NOT calculate any new numbers.
- Do NOT invent any numbers.
- Do NOT change any ranking.
- Do NOT assign a return rate to any specific category.
- Do NOT claim sales are increasing or decreasing.
- Do NOT use external industry benchmarks.
- Do NOT create numerical values that are not explicitly provided.
- You may repeat the exact percentages provided.
- Focus on business interpretation and actionable recommendations.

Generate:

### 1. Key Business Insights
Give exactly 5 insights.

### 2. Business Problems
Give exactly 3 problems that are directly supported by the facts.

### 3. Recommendations
Give exactly 5 practical recommendations.

### 4. Management Summary
Write a short professional summary.

Remember:
Python has already performed the numerical analysis.
Your job is ONLY to interpret the verified results.
"""

messages = [
    {
        "role": "system",
        "content": """
You are a grounded e-commerce analyst.
Never invent data.
Never perform additional calculations.
Only interpret verified facts supplied by Python.
"""
    },
    {
        "role": "user",
        "content": safe_analysis_prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=800,
        do_sample=False
    )

safe_final_report = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(safe_final_report)
# Out:
# ### 1. Key Business Insights
#
# 1. **Electronics Dominates Sales and Profit**: Electronics consistently ranks first in both total sales and profit, indicating it is a critical revenue generator for the company.
# 2. **Furniture and Home & Kitchen Follow**: These categories follow closely behind Electronics in terms of both sales and profit, suggesting they are also significant contributors to the business.
# 3. **Beauty Category Leads in Profit Margin**: The Beauty category leads in profit margin, highlighting its profitability potential and the importance of maintaining high margins in this area.
# 4. **Fashion and Books Have High Profit Margins**: Fashion and Books have strong profit margins, which could be leveraged for strategic marketing and product development.
# 5. **Return Rate Remains Stable**: The overall return rate remains steady at 4.76%, indicating a relatively low level of customer dissatisfaction and a stable customer retention strategy.
#
# ### 2. Business Problems
# ...

# %%
final_safe_prompt = f"""
You are an e-commerce business analyst.

Use ONLY these verified facts:

{safe_facts}

STRICT DATA RULES:

1. Electronics is #1 in Total Sales.
2. Furniture is #2 in Total Sales.
3. Home & Kitchen is #3 in Total Sales.
4. Electronics is #1 in Total Profit.
5. Home & Kitchen is #2 in Total Profit.
6. Fashion is #3 in Total Profit.
7. Beauty has the highest Profit Margin at 56.69%.
8. Books has the second-highest Profit Margin at 46.21%.
9. Fashion has the third-highest Profit Margin at 45.96%.
10. Electronics Profit Margin is 14.23%.
11. Overall Return Rate is 4.76%.
12. Total Orders are 30,000.

CRITICAL:
- The 4.76% return rate is ONLY an overall business metric.
- NEVER say that any particular category has a 4.76% return rate.
- NEVER discuss category-specific returns.
- NEVER say the return rate is stable, increasing, or decreasing.
- Do not say Furniture or Home & Kitchen sales are increasing/decreasing.
- Do not call Fashion or Books low-margin categories.
- Do not calculate any new numbers.
- Do not invent any information.
- Do not use external benchmarks.

Generate:

### Key Business Insights
Exactly 5 insights.

### Business Problems
Exactly 3 problems supported by the verified facts.

### Recommendations
Exactly 5 actionable recommendations.

### Management Summary
A concise professional summary.

Only discuss facts that can be directly supported by the verified information.
"""

messages = [
    {
        "role": "system",
        "content": """
You are a strict data-grounded e-commerce analyst.
Python-generated facts are authoritative.
Never invent missing information.
Never assign overall metrics to individual categories.
"""
    },
    {
        "role": "user",
        "content": final_safe_prompt
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    text,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=800,
        do_sample=False
    )

final_grounded_report = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)

print(final_grounded_report)
# Out:
# ### Key Business Insights
#
# 1. **Electronics leads in both Total Sales and Total Profit.**
# 2. **Home & Kitchen ranks second in Total Sales and Total Profit.**
# 3. **Fashion has the highest Profit Margin among all categories.**
# 4. **Beauty has the second-highest Profit Margin.**
# 5. **Books have the third-highest Profit Margin.**
#
# ### Business Problems
#
# 1. **Low Profit Margin for Fashion.**
#    - Fashion's Profit Margin of 45.96% is significantly lower than the highest margin of 56.69% for Beauty.
#
# 2. **High Return Rate for Fashion.**
#    - Despite having a high profit margin, Fashion faces a high return rate of 4.76%, which could indicate issues with product quality or customer satisfaction.
#
# 3. **Declining Sales for Home & Kitchen.**
#    - While Home & Kitchen ranks third in Total Sales, its performance in Total Profit is only second, suggesting potential challenges in maintaining profitability.
#
# ### Recommendations
#
# ...

# %%
def ask_business_question(question):

    prompt = f"""
You are an e-commerce data analyst.

Answer the user's question using ONLY the verified business facts below.

VERIFIED FACTS:
{safe_facts}

STRICT RULES:
- Never invent data.
- Never calculate new numbers.
- Never assign overall metrics to individual categories.
- If the required information is not available, say:
  "This information is not available in the current analysis."
- Give a short, clear, business-oriented answer.

USER QUESTION:
{question}
"""

    messages = [
        {
            "role": "system",
            "content": "You are a grounded e-commerce business analyst."
        },
        {
            "role": "user",
            "content": prompt
        }
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        text,
        return_tensors="pt"
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            do_sample=False
        )

    answer = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[1]:],
        skip_special_tokens=True
    )

    return answer

# %%
print("Function ready:", callable(ask_business_question))
# Out:
# Function ready: True

# %%
answer = ask_business_question(
    "Which category should management focus on and why?"
)

print("===== AI BUSINESS ANSWER =====")
print(answer)
# Out:
# ===== AI BUSINESS ANSWER =====
# Management should focus on Electronics as it has the highest Total Sales and Total Profit. This indicates strong market demand and profitability for this category.

# %%
answer = ask_business_question(
    "Which category has the highest profit margin?"
)

print("===== AI BUSINESS ANSWER =====")
print(answer)
# Out:
# ===== AI BUSINESS ANSWER =====
# Beauty has the highest profit margin at 56.69%.

# %%
answer = ask_business_question(
    "Which category has the highest return rate?"
)

print("===== AI BUSINESS ANSWER =====")
print(answer)
# Out:
# ===== AI BUSINESS ANSWER =====
# This information is not available in the current analysis.

# %%
print("======================================")
print("   E-COMMERCE GENAI BUSINESS ANALYST")
print("======================================")
print("Type 'exit' to stop.\n")

while True:
    question = input("Ask your business question: ")

    if question.lower().strip() == "exit":
        print("GenAI Analyst stopped.")
        break

    if question.strip() == "":
        print("Please enter a question.\n")
        continue

    answer = ask_business_question(question)

    print("\n===== AI BUSINESS ANSWER =====")
    print(answer)
    print()
# Out:
# ...
#    E-COMMERCE GENAI BUSINESS ANALYST
# ...
# Type 'exit' to stop.
#
# Ask your business question: what is the totalsale
#
# ===== AI BUSINESS ANSWER =====
# The total sales for the Electronics category is the highest among all categories.
#
# Ask your business question: Which category should management focus on?
#
# ===== AI BUSINESS ANSWER =====
# Management should focus on Electronics, as it has both the highest Total Sales and Total Profit among all categories.
#
# Ask your business question: exit
# GenAI Analyst stopped.

# %%
safe_facts = f"""
VERIFIED BUSINESS FACTS

OVERALL BUSINESS KPI:
- Total Orders: 30,000
- Total Sales: ₹201,410,807.72
- Total Profit: ₹48,090,891.94
- Total Refund: ₹10,705,212.31
- Profit Margin: 23.88%
- Returned Orders: 1,427
- Overall Return Rate: 4.76%
- Average Order Value: ₹6,713.69

CATEGORY RANKINGS:

TOP 3 BY TOTAL SALES:
1. Electronics
2. Furniture
3. Home & Kitchen

TOP 3 BY TOTAL PROFIT:
1. Electronics
2. Home & Kitchen
3. Fashion

TOP 3 BY PROFIT MARGIN:
1. Beauty — 56.69%
2. Books — 46.21%
3. Fashion — 45.96%

ADDITIONAL VERIFIED FACT:
- Electronics Profit Margin: 14.23%

IMPORTANT:
- Overall KPI values describe the entire business.
- Category rankings describe individual categories.
- Overall Return Rate of 4.76% must NOT be assigned to any category.
- Do not invent category-specific return rates.
- Do not invent sales/profit values for individual categories.
- Do not claim sales are increasing or decreasing.
"""
print(safe_facts)
# Out:
# VERIFIED BUSINESS FACTS
#
# OVERALL BUSINESS KPI:
# - Total Orders: 30,000
# - Total Sales: ₹201,410,807.72
# - Total Profit: ₹48,090,891.94
# - Total Refund: ₹10,705,212.31
# - Profit Margin: 23.88%
# - Returned Orders: 1,427
# - Overall Return Rate: 4.76%
# - Average Order Value: ₹6,713.69
#
# CATEGORY RANKINGS:
#
# TOP 3 BY TOTAL SALES:
# 1. Electronics
# 2. Furniture
# 3. Home & Kitchen
#
# TOP 3 BY TOTAL PROFIT:
# 1. Electronics
# 2. Home & Kitchen
# 3. Fashion
#
# TOP 3 BY PROFIT MARGIN:
# 1. Beauty — 56.69%
# 2. Books — 46.21%
# 3. Fashion — 45.96%
#
# ADDITIONAL VERIFIED FACT:
# - Electronics Profit Margin: 14.23%
#
# IMPORTANT:
# - Overall KPI values describe the entire business.
# - Category rankings describe individual categories.
# - Overall Return Rate of 4.76% must NOT be assigned to any category.
# - Do not invent category-specific return rates.
# - Do not invent sales/profit values for individual categories.
# - Do not claim sales are increasing or decreasing.

# %%
def ask_business_question(question):

    prompt = f"""
You are an e-commerce business analyst.

Use ONLY the verified business facts provided below.

{safe_facts}

IMPORTANT INSTRUCTIONS:

1. If the user asks for an OVERALL business KPI:
   - Use the OVERALL BUSINESS KPI section.
   - Do not answer with a category value.

2. If the user asks about a CATEGORY:
   - Use the CATEGORY RANKINGS or ADDITIONAL VERIFIED FACT section.

3. If the user asks:
   "What is the total sales?"
   "What are total sales?"
   "How much did the business sell?"
   → Answer with the OVERALL Total Sales.

4. If the user asks:
   "Which category has the highest sales?"
   → Answer Electronics.

5. If the user asks:
   "Which category has the highest profit?"
   → Answer Electronics.

6. If the user asks:
   "Which category has the highest profit margin?"
   → Answer Beauty and mention 56.69%.

7. The 4.76% return rate is an OVERALL business metric.
   NEVER assign it to a category.

8. NEVER invent missing values.

9. NEVER calculate new numbers.

10. NEVER claim a trend such as increasing or decreasing unless explicitly provided.

11. Keep the answer concise and business-focused.

USER QUESTION:
{question}
"""

    messages = [
        {
            "role": "system",
            "content": """
You are a strict, grounded e-commerce business analyst.
Python-generated verified facts are authoritative.
Always distinguish overall business KPIs from category-level information.
Never hallucinate missing data.
"""
        },
        {
            "role": "user",
            "content": prompt
        }
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        text,
        return_tensors="pt"
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=250,
            do_sample=False
        )

    answer = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[1]:],
        skip_special_tokens=True
    )

    return answer.strip()

# %%
print(ask_business_question("What is the total sales?"))
# Out:
# The total sales are ₹201,410,807.72.

# %%
print("TEST 1:")
print(ask_business_question("What is the total sales?"))

print("\nTEST 2:")
print(ask_business_question("Which category has the highest sales?"))

print("\nTEST 3:")
print(ask_business_question("Which category has the highest profit margin?"))

print("\nTEST 4:")
print(ask_business_question("Which category has the highest return rate?"))
# Out:
# TEST 1:
# The total sales are ₹201,410,807.72.
#
# TEST 2:
# Electronics
#
# TEST 3:
# Beauty has the highest profit margin at 56.69%.
#
# TEST 4:
# The overall return rate is 4.76%, but this metric is not assigned to any specific category.

# %%
# !pip install -q gradio

# %%
import gradio as gr

def genai_answer(question):
    if not question.strip():
        return "Please enter a business question."

    return ask_business_question(question)

print("Gradio function ready!")
# Out:
# Gradio function ready!

# %%
import gradio as gr

demo = gr.Interface(
    fn=genai_answer,
    inputs=gr.Textbox(
        label="Ask your business question",
        placeholder="e.g. Which category has the highest profit margin?"
    ),
    outputs=gr.Textbox(
        label="AI Business Answer"
    ),
    title="🛒 E-Commerce GenAI Business Analyst",
    description="Ask questions about verified e-commerce business data."
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://13f5bcd5c3c7c53b47.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://13f5bcd5c3c7c53b47.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
print("Ready for Step 87")
# Out:
# Ready for Step 87

# %%
dashboard_kpi = {
    "Total Orders": 30000,
    "Total Sales": 201410807.72,
    "Total Profit": 48090891.94,
    "Profit Margin": 23.88,
    "Return Rate": 4.76,
    "Average Order Value": 6713.69
}

print("===== DASHBOARD KPI =====")

for key, value in dashboard_kpi.items():
    if key in ["Total Sales", "Total Profit", "Average Order Value"]:
        print(f"{key}: ₹{value:,.2f}")
    elif key in ["Profit Margin", "Return Rate"]:
        print(f"{key}: {value:.2f}%")
    else:
        print(f"{key}: {value:,}")
# Out:
# ===== DASHBOARD KPI =====
# Total Orders: 30,000
# Total Sales: ₹201,410,807.72
# Total Profit: ₹48,090,891.94
# Profit Margin: 23.88%
# Return Rate: 4.76%
# Average Order Value: ₹6,713.69

# %%
category_dashboard = category_analysis[
    ["Total_Sales", "Total_Profit"]
].sort_values(
    "Total_Sales",
    ascending=False
)

print("===== CATEGORY PERFORMANCE =====")
print(category_dashboard.round(2))
# Out:
# ===== CATEGORY PERFORMANCE =====
#                  Total_Sales  Total_Profit
# Category
# Electronics     1.160483e+08   16513179.67
# Furniture       1.981540e+07    5172984.94
# Home & Kitchen  1.748387e+07    6759708.74
# Fashion         1.138593e+07    5233231.91
# Automotive      1.055978e+07    3557936.10
# Sports          7.619502e+06    2943538.77
# Toys            5.429559e+06    2398466.88
# Pet Supplies    4.948905e+06    1696635.62
# Beauty          3.698403e+06    2096495.98
# Books           2.743873e+06    1268049.96
# Grocery         1.677245e+06     450663.37

# %%
margin_dashboard = category_analysis[
    ["Profit_Margin_%"]
].sort_values(
    "Profit_Margin_%",
    ascending=False
)

print("===== CATEGORY PROFIT MARGIN =====")
print(margin_dashboard.round(2))
# Out:
# ===== CATEGORY PROFIT MARGIN =====
#                 Profit_Margin_%
# Category
# Beauty                    56.69
# Books                     46.21
# Fashion                   45.96
# Toys                      44.17
# Home & Kitchen            38.66
# Sports                    38.63
# Pet Supplies              34.28
# Automotive                33.69
# Grocery                   26.87
# Furniture                 26.11
# Electronics               14.23

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.bar(
    category_dashboard.index,
    category_dashboard["Total_Sales"]
)

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales (₹)")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

profit_chart = category_dashboard.sort_values(
    "Total_Profit",
    ascending=False
)

plt.figure(figsize=(12, 6))

plt.bar(
    profit_chart.index,
    profit_chart["Total_Profit"]
)

plt.title("Total Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit (₹)")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.bar(
    margin_dashboard.index,
    margin_dashboard["Profit_Margin_%"]
)

plt.title("Profit Margin by Category")
plt.xlabel("Category")
plt.ylabel("Profit Margin (%)")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
import gradio as gr

with gr.Blocks(title="E-Commerce GenAI Business Analyst") as app:

    gr.Markdown("# 🛒 E-Commerce GenAI Business Analyst")
    gr.Markdown("### AI-powered business insights from verified e-commerce data")

    gr.Markdown("## 📊 Overall Business KPIs")

    with gr.Row():
        gr.Markdown("**Total Orders**\n\n30,000")
        gr.Markdown("**Total Sales**\n\n₹201,410,807.72")
        gr.Markdown("**Total Profit**\n\n₹48,090,891.94")

    with gr.Row():
        gr.Markdown("**Profit Margin**\n\n23.88%")
        gr.Markdown("**Return Rate**\n\n4.76%")
        gr.Markdown("**Average Order Value**\n\n₹6,713.69")

    gr.Markdown("## 🤖 Ask the GenAI Business Analyst")

    question = gr.Textbox(
        label="Business Question",
        placeholder="e.g. Which category has the highest profit margin?"
    )

    ask_button = gr.Button("Ask AI")

    answer = gr.Textbox(
        label="AI Business Answer",
        lines=4
    )

    ask_button.click(
        fn=genai_answer,
        inputs=question,
        outputs=answer
    )

print("Dashboard UI created successfully!")
# Out:
# Dashboard UI created successfully!

# %%
app.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9b438aa154c8e3bc02.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9b438aa154c8e3bc02.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
sales_plot = plt.figure(figsize=(12, 6))

plt.bar(
    category_dashboard.index,
    category_dashboard["Total_Sales"]
)

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales (₹)")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def create_sales_chart():
    fig, ax = plt.subplots(figsize=(12, 6))

    ax.bar(
        category_dashboard.index,
        category_dashboard["Total_Sales"]
    )

    ax.set_title("Total Sales by Category")
    ax.set_xlabel("Category")
    ax.set_ylabel("Sales (₹)")
    ax.tick_params(axis="x", rotation=45)

    fig.tight_layout()
    return fig


sales_chart = create_sales_chart()

print("Sales chart ready for dashboard!")
# Out:
# Sales chart ready for dashboard!

# %%
with gr.Blocks(title="E-Commerce GenAI Business Analyst") as final_app:

    gr.Markdown("# 🛒 E-Commerce GenAI Business Analyst")
    gr.Markdown("### AI-powered business insights from verified e-commerce data")

    gr.Markdown("## 📊 Overall Business KPIs")

    with gr.Row():
        gr.Markdown("### Total Orders\n30,000")
        gr.Markdown("### Total Sales\n₹201,410,807.72")
        gr.Markdown("### Total Profit\n₹48,090,891.94")

    with gr.Row():
        gr.Markdown("### Profit Margin\n23.88%")
        gr.Markdown("### Return Rate\n4.76%")
        gr.Markdown("### Average Order Value\n₹6,713.69")

    gr.Markdown("## 📈 Sales by Category")

    gr.Plot(
        value=sales_chart,
        label="Total Sales by Category"
    )

print("Final dashboard created successfully!")
# Out:
# Final dashboard created successfully!

# %%
def create_profit_chart():
    data = category_dashboard.sort_values(
        "Total_Profit",
        ascending=False
    )

    fig, ax = plt.subplots(figsize=(12, 6))

    ax.bar(
        data.index,
        data["Total_Profit"]
    )

    ax.set_title("Total Profit by Category")
    ax.set_xlabel("Category")
    ax.set_ylabel("Profit (₹)")
    ax.tick_params(axis="x", rotation=45)

    fig.tight_layout()
    return fig


def create_margin_chart():
    data = margin_dashboard.sort_values(
        "Profit_Margin_%",
        ascending=False
    )

    fig, ax = plt.subplots(figsize=(12, 6))

    ax.bar(
        data.index,
        data["Profit_Margin_%"]
    )

    ax.set_title("Profit Margin by Category")
    ax.set_xlabel("Category")
    ax.set_ylabel("Profit Margin (%)")
    ax.tick_params(axis="x", rotation=45)

    fig.tight_layout()
    return fig


profit_chart = create_profit_chart()
margin_chart = create_margin_chart()

print("Profit and margin charts ready!")
# Out:
# Profit and margin charts ready!

# %%
with gr.Blocks(title="E-Commerce GenAI Business Analyst") as final_dashboard:

    gr.Markdown("# 🛒 E-Commerce GenAI Business Analyst")
    gr.Markdown("### AI-powered business insights from verified e-commerce data")

    gr.Markdown("## 📊 Overall Business KPIs")

    with gr.Row():
        gr.Markdown("### Total Orders\n30,000")
        gr.Markdown("### Total Sales\n₹201,410,807.72")
        gr.Markdown("### Total Profit\n₹48,090,891.94")

    with gr.Row():
        gr.Markdown("### Profit Margin\n23.88%")
        gr.Markdown("### Return Rate\n4.76%")
        gr.Markdown("### Average Order Value\n₹6,713.69")

    gr.Markdown("## 📈 Category Performance")

    gr.Plot(
        value=sales_chart,
        label="Total Sales by Category"
    )

    gr.Plot(
        value=profit_chart,
        label="Total Profit by Category"
    )

    gr.Plot(
        value=margin_chart,
        label="Profit Margin by Category"
    )

    gr.Markdown("## 🤖 Ask the GenAI Business Analyst")

    question = gr.Textbox(
        label="Business Question",
        placeholder="e.g. Which category has the highest profit margin?"
    )

    ask_button = gr.Button("🚀 Ask AI")

    answer = gr.Textbox(
        label="AI Business Answer",
        lines=5
    )

    ask_button.click(
        fn=genai_answer,
        inputs=question,
        outputs=answer
    )

print("======================================")
print("FINAL DASHBOARD CREATED SUCCESSFULLY!")
print("======================================")
# Out:
# ...
# FINAL DASHBOARD CREATED SUCCESSFULLY!
# ...

# %%
final_dashboard.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://187e78b2182516a265.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://187e78b2182516a265.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
